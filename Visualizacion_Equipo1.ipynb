# %% [markdown]
# <a href="https://colab.research.google.com/github/Jose-Manuel-Romero-Banda/Mineria-de-Datos/blob/main/Visualizacion_Equipo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Equipo 1
# ## Grupo: 001 (Lunes 7:00 - 10:00 pm)
# ### Integrantes:
# + 1848655 - Rangel Vallejo Isabel Alejandra
# + 1851167 - Aguilar Sánchez José Antonio
# + 1851124 - Cerecero Peña Angela Scarlett
# + 1851528 - Romero Banda José Manuel
# + 1853849 - García Gutiérrez Alfonso de Jesús

# %% [markdown]
# # CO2 Emission by Vehicles

# %% [markdown]
# **1) Título de la base de datos**
# a) Nombre con el que se encuentra en la página: **"CO2 Emission by Vehicles"**
# b) Url de la página: [CO2 Emission](https://www.kaggle.com/debajyotipodder/co2-emission-by-vehicles)

# %% [markdown]
# #**PRÁCTICA DE VISUALIZACIÓN DE DATOS**

# %% [markdown]
# Primero importamos la librería

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import pandas_profiling
import matplotlib.pyplot as plt

# %% [markdown]
# Leemos nuestra base de datos y mostramos una visualización general de ésta.

# %%
baseCO2 = pd.read_csv('CO2-Emissions_Canada.csv', sep=',')
baseCO2
# Out:
#        Make        Model  ... Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0     ACURA          ILX  ...                          33                  196
# 1     ACURA          ILX  ...                          29                  221
# 2     ACURA   ILX HYBRID  ...                          48                  136
# 3     ACURA      MDX 4WD  ...                          25                  255
# 4     ACURA      RDX AWD  ...                          27                  244
# ...     ...          ...  ...                         ...                  ...
# 7380  VOLVO  XC40 T5 AWD  ...                          30                  219
# 7381  VOLVO  XC60 T5 AWD  ...                          29                  232
# 7382  VOLVO  XC60 T6 AWD  ...                          27                  240
# 7383  VOLVO  XC90 T5 AWD  ...                          29                  232
# 7384  VOLVO  XC90 T6 AWD  ...                          26                  248
#
# ...

# %% [markdown]
# Como vemos en la impresión anterior nuestro dataframe tiene 7385 filas y 12 columnas.
#
# Revisamos los nombres de las columnas:

# %%
baseCO2.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %% [markdown]
# Ahora nos interesa ver el tipo de dato que tiene cada columna para saber con cuales columnas podemos hacer un análisis estadístico básico.

# %%
baseCO2.dtypes
# Out:
# Make                                 object
# Model                                object
# Vehicle Class                        object
# Engine Size(L)                      float64
# Cylinders                             int64
# Transmission                         object
# Fuel Type                            object
# Fuel Consumption City (L/100 km)    float64
# Fuel Consumption Hwy (L/100 km)     float64
# Fuel Consumption Comb (L/100 km)    float64
# Fuel Consumption Comb (mpg)           int64
# CO2 Emissions(g/km)                   int64
# dtype: object

# %% [markdown]
# Como vemos arriba, las columnas: "Make", "Model", "Vehicle Class", "Transmission" y "Fuel Type" no son de tipo numérico ya sea "int" o sea entero o "float" que son los flotantes, así que no se puede revisar la información estadística básica de estas 5 columnas.

# %% [markdown]
# # **INFORMACIÓN ESTADÍSTICA BÁSICA**

# %% [markdown]
# ##Columna "Engine Size(L)":
#
# ##Representa el tamaño del motor del automóvil, viene representado en litros e indican la cantidad de gasolina que utiliza un coche cuando sus cilindros están llenos.

# %%
baseCO2['Engine Size(L)'].sum() #Suma todos los elementos de la columna seleccionada.
# Out:
# 23337.1

# %% [markdown]
# La suma de todos los elementos de la columna "Engine Size(L)" es 23337.1

# %%
baseCO2['Engine Size(L)'].mean() # Promedio.
# Out:
# 3.1600677048070125

# %% [markdown]
# El promedio de los elementos de la columna "Engine Size(L)" es 3.16

# %%
baseCO2['Engine Size(L)'].cumsum() # Suma acumulada de la columna fila por fila.
# Out:
# 0           2.0
# 1           4.4
# 2           5.9
# 3           9.4
# 4          12.9
#          ...
# 7380    23329.1
# 7381    23331.1
# 7382    23333.1
# 7383    23335.1
# 7384    23337.1
# Name: Engine Size(L), Length: 7385, dtype: float64

# %% [markdown]
# Acumulados de la columna fila por fila.

# %%
baseCO2['Engine Size(L)'].describe() # Resumen estadístico de la columna.
# Out:
# count    7385.000000
# mean        3.160068
# std         1.354170
# min         0.900000
# 25%         2.000000
# 50%         3.000000
# 75%         3.700000
# max         8.400000
# Name: Engine Size(L), dtype: float64

# %% [markdown]
# Resumen estadístico de la columna "Engine Size(L)", en éste se muestran distintos datos como: la media, desviación estándar, mínimo. máximo y sus cuartiles.

# %%
baseCO2['Engine Size(L)'].count() # Cuantos elementos no nulos hay en la columna.
# Out:
# 7385

# %% [markdown]
# Como vemos tenemos 7385 elementos no nulos y nuestra base de datos tiene 7385 filas así que no nos hace falta ningún dato de esta columna.

# %%
baseCO2['Engine Size(L)'].min() # min de una columna.
# Out:
# 0.9

# %% [markdown]
# El valor más pequeño de la columna es 0.9

# %%
baseCO2['Engine Size(L)'].max() # máximo de una columna.
# Out:
# 8.4

# %% [markdown]
# El valor más grande de la columna es 8.4

# %%
baseCO2['Engine Size(L)'].median()
# Out:
# 3.0

# %% [markdown]
# La mediana de la columna es 3.

# %%
baseCO2['Engine Size(L)'].var()
# Out:
# 1.833777622717723

# %% [markdown]
# La varianza de la columna es 1.833

# %%
baseCO2['Engine Size(L)'].std()
# Out:
# 1.354170455562269

# %% [markdown]
# La desviación estándar de la columna es 1.354

# %%
baseCO2['Engine Size(L)'].skew() # Valor de asimetría en los datos.
# Out:
# 0.8091809893113103

# %% [markdown]
# El valor de asimetría en los datos de esta columna es de 0.8091

# %%
baseCO2['Engine Size(L)'].kurt() # Característica de forma de su distribución de frecuencias/probabilidad.
# Out:
# -0.1319632848497747

# %% [markdown]
# Ya que este número es menor a cero se dice que se tiene una forma en su distribución de probabilidad "platicúrtica".

# %% [markdown]
# ##Columna "Cylinders":
#
# ##Cantidad de cilindros que tiene el vehículo.

# %%
baseCO2['Cylinders'].sum()
# Out:
# 41467

# %% [markdown]
# La suma de todos los elementos de la columna "Cylinders" es 41467

# %%
baseCO2['Cylinders'].mean()
# Out:
# 5.615030467163169

# %% [markdown]
# El promedio de los elementos de la columna "Cylinders" es 5.61

# %%
baseCO2['Cylinders'].cumsum()
# Out:
# 0           4
# 1           8
# 2          12
# 3          18
# 4          24
#         ...
# 7380    41451
# 7381    41455
# 7382    41459
# 7383    41463
# 7384    41467
# Name: Cylinders, Length: 7385, dtype: int64

# %% [markdown]
# Acumulados de la columna fila por fila.

# %%
baseCO2['Cylinders'].describe()
# Out:
# count    7385.000000
# mean        5.615030
# std         1.828307
# min         3.000000
# 25%         4.000000
# 50%         6.000000
# 75%         6.000000
# max        16.000000
# Name: Cylinders, dtype: float64

# %% [markdown]
# Resumen estadístico de la columna "Cylinders", en éste se muestran distintos datos como: la media, desviación estándar, mínimo. máximo y sus cuartiles.

# %%
baseCO2['Cylinders'].count()
# Out:
# 7385

# %% [markdown]
# Como vemos tenemos 7385 elementos no nulos y nuestra base de datos tiene 7385 filas así que no nos hace falta ningún dato de esta columna.

# %%
baseCO2['Cylinders'].min()
# Out:
# 3

# %% [markdown]
# El valor más pequeño de la columna es 3

# %%
baseCO2['Cylinders'].max()
# Out:
# 16

# %% [markdown]
# El valor más grande de la columna es 16

# %%
baseCO2['Cylinders'].median()
# Out:
# 6.0

# %% [markdown]
# La mediana de la columna es 6.

# %%
baseCO2['Cylinders'].var()
# Out:
# 3.3427047153501626

# %% [markdown]
# La varianza de la columna es 3.342

# %%
baseCO2['Cylinders'].std()
# Out:
# 1.8283065156997507

# %% [markdown]
# La desviación estándar de la columna es 1.828

# %%
baseCO2['Cylinders'].skew()
# Out:
# 1.1104154181552897

# %% [markdown]
# El valor de asimetría en los datos de esta columna es de 1.11

# %%
baseCO2['Cylinders'].kurt()
# Out:
# 1.5251749532359167

# %% [markdown]
# Ya que este número es mayor a cero se dice que se tiene una forma en su distribución de probabilidad "leptocúrtica".

# %% [markdown]
# ##Columna "Fuel Consumption City (L/100 km)":
#
# ##Consumo de combustible en la ciudad; se muestra en litros por cada 100 kilómetros (L / 100 km).

# %%
baseCO2['Fuel Consumption City (L/100 km)'].sum()
# Out:
# 92730.0

# %% [markdown]
# La suma de todos los elementos de la columna "Fuel Consumption City (L/100 km)" es 92730.

# %%
baseCO2['Fuel Consumption City (L/100 km)'].mean()
# Out:
# 12.556533513879508

# %% [markdown]
# El promedio de los elementos de la columna "Fuel Consumption City (L/100 km)" es 12.55.

# %%
baseCO2['Fuel Consumption City (L/100 km)'].cumsum()
# Out:
# 0           9.9
# 1          21.1
# 2          27.1
# 3          39.8
# 4          51.9
#          ...
# 7380    92683.7
# 7381    92694.9
# 7382    92706.6
# 7383    92717.8
# 7384    92730.0
# Name: Fuel Consumption City (L/100 km), Length: 7385, dtype: float64

# %% [markdown]
# Acumulados de la columna fila por fila.

# %%
baseCO2['Fuel Consumption City (L/100 km)'].describe()
# Out:
# count    7385.000000
# mean       12.556534
# std         3.500274
# min         4.200000
# 25%        10.100000
# 50%        12.100000
# 75%        14.600000
# max        30.600000
# Name: Fuel Consumption City (L/100 km), dtype: float64

# %% [markdown]
# Resumen estadístico de la columna "Fuel Consumption City (L/100 km)", en éste se muestran distintos datos como: la media, desviación estándar, mínimo. máximo y sus cuartiles.

# %%
baseCO2['Fuel Consumption City (L/100 km)'].count()
# Out:
# 7385

# %% [markdown]
# Como vemos tenemos 7385 elementos no nulos y nuestra base de datos tiene 7385 filas así que no nos hace falta ningún dato de esta columna.

# %%
baseCO2['Fuel Consumption City (L/100 km)'].min()
# Out:
# 4.2

# %% [markdown]
# El valor más pequeño de la columna es 4.2.

# %%
baseCO2['Fuel Consumption City (L/100 km)'].max()
# Out:
# 30.6

# %% [markdown]
# El valor más grande de la columna es 30.6.

# %%
baseCO2['Fuel Consumption City (L/100 km)'].median()
# Out:
# 12.1

# %% [markdown]
# La mediana de la columna es 12.1.

# %%
baseCO2['Fuel Consumption City (L/100 km)'].var()
# Out:
# 12.251918642734974

# %% [markdown]
# La varianza de la columna es 12.25

# %%
baseCO2['Fuel Consumption City (L/100 km)'].std()
# Out:
# 3.5002740810877904

# %% [markdown]
# La desviación estándar de la columna es 3.5002.

# %%
baseCO2['Fuel Consumption City (L/100 km)'].skew()
# Out:
# 0.809004712577022

# %% [markdown]
# El valor de asimetría en los datos de esta columna es de 0.8090.

# %%
baseCO2['Fuel Consumption City (L/100 km)'].kurt()
# Out:
# 1.1961449732393845

# %% [markdown]
# Ya que este número es mayor a cero se dice que se tiene una forma en su distribución de probabilidad "leptocúrtica".

# %% [markdown]
# ##Columna "Fuel Consumption Hwy (L/100 km)":
#
# ##Consumo de combustible en la autopista; se muestra en litros por cada 100 kilómetros (L / 100 km).

# %%
baseCO2['Fuel Consumption Hwy (L/100 km)'].sum()
# Out:
# 66773.0

# %% [markdown]
# La suma de todos los elementos de la columna "Fuel Consumption Hwy (L/100 km)" es 66773.

# %%
baseCO2['Fuel Consumption Hwy (L/100 km)'].mean()
# Out:
# 9.04170616113748

# %% [markdown]
# El promedio de los elementos de la columna "Fuel Consumption Hwy (L/100 km)" es 9.0417.

# %%
baseCO2['Fuel Consumption Hwy (L/100 km)'].cumsum()
# Out:
# 0           6.7
# 1          14.4
# 2          20.2
# 3          29.3
# 4          38.0
#          ...
# 7380    66739.1
# 7381    66747.4
# 7382    66756.0
# 7383    66764.3
# 7384    66773.0
# Name: Fuel Consumption Hwy (L/100 km), Length: 7385, dtype: float64

# %% [markdown]
# Acumulados de la columna fila por fila.

# %%
baseCO2['Fuel Consumption Hwy (L/100 km)'].describe()
# Out:
# count    7385.000000
# mean        9.041706
# std         2.224456
# min         4.000000
# 25%         7.500000
# 50%         8.700000
# 75%        10.200000
# max        20.600000
# Name: Fuel Consumption Hwy (L/100 km), dtype: float64

# %% [markdown]
# Resumen estadístico de la columna "Fuel Consumption Hwy (L/100 km)", en éste se muestran distintos datos como: la media, desviación estándar, mínimo. máximo y sus cuartiles.

# %%
baseCO2['Fuel Consumption Hwy (L/100 km)'].count()
# Out:
# 7385

# %% [markdown]
# Como vemos tenemos 7385 elementos no nulos y nuestra base de datos tiene 7385 filas así que no nos hace falta ningún dato de esta columna.

# %%
baseCO2['Fuel Consumption Hwy (L/100 km)'].min()
# Out:
# 4.0

# %% [markdown]
# El valor más pequeño de la columna es 4.

# %%
baseCO2['Fuel Consumption Hwy (L/100 km)'].max()
# Out:
# 20.6

# %% [markdown]
# El valor más grande de la columna es 20.6

# %%
baseCO2['Fuel Consumption Hwy (L/100 km)'].median()
# Out:
# 8.7

# %% [markdown]
# La mediana de la columna es 8.7.

# %%
baseCO2['Fuel Consumption Hwy (L/100 km)'].var()
# Out:
# 4.948206189378383

# %% [markdown]
# La varianza de la columna es 4.9482.

# %%
baseCO2['Fuel Consumption Hwy (L/100 km)'].std()
# Out:
# 2.2244563806418824

# %% [markdown]
# La desviación estándar de la columna es 2.2244.

# %%
baseCO2['Fuel Consumption Hwy (L/100 km)'].skew()
# Out:
# 1.0792166921679716

# %% [markdown]
# El valor de asimetría en los datos de esta columna es de 1.0792.

# %%
baseCO2['Fuel Consumption Hwy (L/100 km)'].kurt()
# Out:
# 2.0089688957038776

# %% [markdown]
# Ya que este número es mayor a cero se dice que se tiene una forma en su distribución de probabilidad "leptocúrtica".

# %% [markdown]
# ##Columna "Fuel Consumption Comb (L/100 km)":
#
# ##Consumo de combustible combinada (55% en la ciudad y 45% en la carretera); se muestra en litros por cada 100 kilómetros (L / 100 km).

# %%
baseCO2['Fuel Consumption Comb (L/100 km)'].sum()
# Out:
# 81050.9

# %% [markdown]
# La suma de todos los elementos de la columna "Fuel Consumption Comb (L/100 km)" es 81050.9.

# %%
baseCO2['Fuel Consumption Comb (L/100 km)'].mean()
# Out:
# 10.97507109004736

# %% [markdown]
# El promedio de los elementos de la columna "Fuel Consumption Comb (L/100 km)" es 10.9750.

# %%
baseCO2['Fuel Consumption Comb (L/100 km)'].cumsum()
# Out:
# 0           8.5
# 1          18.1
# 2          24.0
# 3          35.1
# 4          45.7
#          ...
# 7380    81010.1
# 7381    81020.0
# 7382    81030.3
# 7383    81040.2
# 7384    81050.9
# Name: Fuel Consumption Comb (L/100 km), Length: 7385, dtype: float64

# %% [markdown]
# Acumulados de la columna fila por fila.

# %%
baseCO2['Fuel Consumption Comb (L/100 km)'].describe()
# Out:
# count    7385.000000
# mean       10.975071
# std         2.892506
# min         4.100000
# 25%         8.900000
# 50%        10.600000
# 75%        12.600000
# max        26.100000
# Name: Fuel Consumption Comb (L/100 km), dtype: float64

# %% [markdown]
# Resumen estadístico de la columna "Fuel Consumption Comb (L/100 km)", en éste se muestran distintos datos como: la media, desviación estándar, mínimo. máximo y sus cuartiles.

# %%
baseCO2['Fuel Consumption Comb (L/100 km)'].count()
# Out:
# 7385

# %% [markdown]
# Como vemos tenemos 7385 elementos no nulos y nuestra base de datos tiene 7385 filas así que no nos hace falta ningún dato de esta columna.

# %%
baseCO2['Fuel Consumption Comb (L/100 km)'].min()
# Out:
# 4.1

# %% [markdown]
# El valor más pequeño de la columna es 4.1.

# %%
baseCO2['Fuel Consumption Comb (L/100 km)'].max()
# Out:
# 26.1

# %% [markdown]
# El valor más grande de la columna es 26.1.

# %%
baseCO2['Fuel Consumption Comb (L/100 km)'].median()
# Out:
# 10.6

# %% [markdown]
# La mediana de la columna es 10.6.

# %%
baseCO2['Fuel Consumption Comb (L/100 km)'].var()
# Out:
# 8.366592712307336

# %% [markdown]
# La varianza de la columna es 8.3665.

# %%
baseCO2['Fuel Consumption Comb (L/100 km)'].std()
# Out:
# 2.892506302898463

# %% [markdown]
# La desviación estándar de la columna es 2.8925.

# %%
baseCO2['Fuel Consumption Comb (L/100 km)'].skew()
# Out:
# 0.893315721747063

# %% [markdown]
# El valor de asimetría en los datos de esta columna es de 0.8933.

# %%
baseCO2['Fuel Consumption Comb (L/100 km)'].kurt()
# Out:
# 1.393575350888704

# %% [markdown]
# Ya que este número es mayor a cero se dice que se tiene una forma en su distribución de probabilidad "leptocúrtica".

# %% [markdown]
# ##Columna "Fuel Consumption Comb (mpg)":
#
# ##Consumo de combustible combinada (55% en la ciudad y 45% en la carretera); se muestra en millas por galón (mpg)

# %%
baseCO2['Fuel Consumption Comb (mpg)'].sum()
# Out:
# 202952

# %% [markdown]
# La suma de todos los elementos de la columna "Fuel Consumption Comb (mpg)" es 202952.

# %%
baseCO2['Fuel Consumption Comb (mpg)'].mean()
# Out:
# 27.48165199729181

# %% [markdown]
# El promedio de los elementos de la columna "Fuel Consumption Comb (mpg)" es 27.4816.

# %%
baseCO2['Fuel Consumption Comb (mpg)'].cumsum()
# Out:
# 0           33
# 1           62
# 2          110
# 3          135
# 4          162
#          ...
# 7380    202841
# 7381    202870
# 7382    202897
# 7383    202926
# 7384    202952
# Name: Fuel Consumption Comb (mpg), Length: 7385, dtype: int64

# %% [markdown]
# Acumulados de la columna fila por fila.

# %%
baseCO2['Fuel Consumption Comb (mpg)'].describe()
# Out:
# count    7385.000000
# mean       27.481652
# std         7.231879
# min        11.000000
# 25%        22.000000
# 50%        27.000000
# 75%        32.000000
# max        69.000000
# Name: Fuel Consumption Comb (mpg), dtype: float64

# %% [markdown]
# Resumen estadístico de la columna "Fuel Consumption Comb (mpg)", en éste se muestran distintos datos como: la media, desviación estándar, mínimo. máximo y sus cuartiles.

# %%
baseCO2['Fuel Consumption Comb (mpg)'].count()
# Out:
# 7385

# %% [markdown]
# Como vemos tenemos 7385 elementos no nulos y nuestra base de datos tiene 7385 filas así que no nos hace falta ningún dato de esta columna.

# %%
baseCO2['Fuel Consumption Comb (mpg)'].min()
# Out:
# 11

# %% [markdown]
# El valor más pequeño de la columna es 11.

# %%
baseCO2['Fuel Consumption Comb (mpg)'].max()
# Out:
# 69

# %% [markdown]
# El valor más grande de la columna es 69.

# %%
baseCO2['Fuel Consumption Comb (mpg)'].median()
# Out:
# 27.0

# %% [markdown]
# La mediana de la columna es 27.

# %%
baseCO2['Fuel Consumption Comb (mpg)'].var()
# Out:
# 52.30007636045897

# %% [markdown]
# La varianza de la columna es 52.3000.

# %%
baseCO2['Fuel Consumption Comb (mpg)'].std()
# Out:
# 7.231879172141841

# %% [markdown]
# La desviación estándar de la columna es 7.2318.

# %%
baseCO2['Fuel Consumption Comb (mpg)'].skew()
# Out:
# 0.9770340609789473

# %% [markdown]
# El valor de asimetría en los datos de esta columna es de 0.9770.

# %%
baseCO2['Fuel Consumption Comb (mpg)'].kurt()
# Out:
# 2.4993690355238343

# %% [markdown]
# Ya que este número es mayor a cero se dice que se tiene una forma en su distribución de probabilidad "leptocúrtica".

# %% [markdown]
# ##Columna "CO2 Emissions(g/km)":
#
# ##Emisiones de dióxido de carbono del tubo de escape (en gramos por kilómetro) de una conducción combinada en ciudad y carretera.

# %%
baseCO2['CO2 Emissions(g/km)'].sum()
# Out:
# 1850568

# %% [markdown]
# La suma de todos los elementos de la columna "CO2 Emissions(g/km)" es 1850568.

# %%
baseCO2['CO2 Emissions(g/km)'].mean()
# Out:
# 250.58469871360867

# %% [markdown]
# El promedio de los elementos de la columna "CO2 Emissions(g/km)" es 250.5846.

# %%
baseCO2['CO2 Emissions(g/km)'].cumsum()
# Out:
# 0           196
# 1           417
# 2           553
# 3           808
# 4          1052
#          ...
# 7380    1849616
# 7381    1849848
# 7382    1850088
# 7383    1850320
# 7384    1850568
# Name: CO2 Emissions(g/km), Length: 7385, dtype: int64

# %% [markdown]
# Acumulados de la columna fila por fila.

# %%
baseCO2['CO2 Emissions(g/km)'].describe()
# Out:
# count    7385.000000
# mean      250.584699
# std        58.512679
# min        96.000000
# 25%       208.000000
# 50%       246.000000
# 75%       288.000000
# max       522.000000
# Name: CO2 Emissions(g/km), dtype: float64

# %% [markdown]
# Resumen estadístico de la columna "CO2 Emissions(g/km)", en éste se muestran distintos datos como: la media, desviación estándar, mínimo. máximo y sus cuartiles.

# %%
baseCO2['CO2 Emissions(g/km)'].count()
# Out:
# 7385

# %% [markdown]
# Como vemos tenemos 7385 elementos no nulos y nuestra base de datos tiene 7385 filas así que no nos hace falta ningún dato de esta columna.

# %%
baseCO2['CO2 Emissions(g/km)'].min()
# Out:
# 96

# %% [markdown]
# El valor más pequeño de la columna es 96.

# %%
baseCO2['CO2 Emissions(g/km)'].max()
# Out:
# 522

# %% [markdown]
# El valor más grande de la columna es 522.

# %%
baseCO2['CO2 Emissions(g/km)'].median()
# Out:
# 246.0

# %% [markdown]
# La mediana de la columna es 246.

# %%
baseCO2['CO2 Emissions(g/km)'].var()
# Out:
# 3423.7336499126

# %% [markdown]
# La varianza de la columna es 3423.7336.

# %%
baseCO2['CO2 Emissions(g/km)'].std()
# Out:
# 58.512679394406476

# %% [markdown]
# La desviación estándar de la columna es 58.5126.

# %%
baseCO2['CO2 Emissions(g/km)'].skew()
# Out:
# 0.5260938068064506

# %% [markdown]
# El valor de asimetría en los datos de esta columna es de 0.5260.

# %%
baseCO2['CO2 Emissions(g/km)'].kurt()
# Out:
# 0.47880085031889585

# %% [markdown]
# Ya que este número es mayor a cero se dice que se tiene una forma en su distribución de probabilidad "leptocúrtica".

# %% [markdown]
# # **CORRELACIÓN Y COVARIANZA DE LOS DATOS**

# %%
print('Correlacion de los datos')
print(baseCO2.corr()) # Correlación de los datos
# Out:
# Correlacion de los datos
#                                   Engine Size(L)  ...  CO2 Emissions(g/km)
# Engine Size(L)                          1.000000  ...             0.851145
# Cylinders                               0.927653  ...             0.832644
# Fuel Consumption City (L/100 km)        0.831379  ...             0.919592
# Fuel Consumption Hwy (L/100 km)         0.761526  ...             0.883536
# Fuel Consumption Comb (L/100 km)        0.817060  ...             0.918052
# Fuel Consumption Comb (mpg)            -0.757854  ...            -0.907426
# CO2 Emissions(g/km)                     0.851145  ...             1.000000
#
# [7 rows x 7 columns]

# %%
print('Covarianza de los datos')
print(baseCO2.cov()) # Covarianza de los datos.
# Out:
# Covarianza de los datos
#                                   Engine Size(L)  ...  CO2 Emissions(g/km)
# Engine Size(L)                          1.833778  ...            67.441418
# Cylinders                               2.296719  ...            89.075474
# Fuel Consumption City (L/100 km)        3.940709  ...           188.342117
# Fuel Consumption Hwy (L/100 km)         2.293939  ...           115.000069
# Fuel Consumption Comb (L/100 km)        3.200380  ...           155.378662
# Fuel Consumption Comb (mpg)            -7.421812  ...          -383.983447
# CO2 Emissions(g/km)                    67.441418  ...          3423.733650
#
# [7 rows x 7 columns]

# %% [markdown]
# Como vemos en lo anterior mostrado la matriz de correlación tiene su diagonal principal llena de unos como es de esperarse.

# %% [markdown]
# # **GRÁFICAS**

# %% [markdown]
# Comenzaremos revisando los nombres de las columnas.

# %%
baseCO2.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %% [markdown]
# Los nombres de las columnas son los elementos que se han impreso. Podemos notar a simple vista que estos elementos están en inglés.
#
# Algunos de estos nombres no son lo suficientemente claros para hacer referencia a los elementos que contiene cada columna, de la misma manera, algunos nombres tienen espacios entre palabras, lo que podría generar un problema al momento de querer referenciar elementos que pertenezcan a dicha columna.
#
# Por esto último, se opta por cambiar los nombres de algunas columnas, con el fin de facilitar el manejo de los datos

# %%
# se crea nueva base con las modificaciones de los nombres de columnas
base_nueva = baseCO2.rename(columns = {'Vehicle Class':'Vehicle_Class','Engine Size(L)':'Engine_Size(L)',
                                       'Fuel Type':'Fuel_Type','Fuel Consumption City (L/100 km)':'Fuel_Consumption_City(L/100 km)',
                                       'Fuel Consumption Hwy (L/100 km)':'Fuel_Consumption_Hwy(L/100 km)',
                                       'Fuel Consumption Comb (L/100 km)':'Fuel_Consumption_Comb(L/100 km)',
                                        'Fuel Consumption Comb (mpg)':'Fuel_Consumption_Comb(mpg)',
                                       'CO2 Emissions(g/km)':'CO2_Emissions(g/km)'})

# %% [markdown]
# Corroboramos que el cambio se haya realizado:

# %%
base_nueva.columns
# Out:
# Index(['Make', 'Model', 'Vehicle_Class', 'Engine_Size(L)', 'Cylinders',
#        'Transmission', 'Fuel_Type', 'Fuel_Consumption_City(L/100 km)',
#        'Fuel_Consumption_Hwy(L/100 km)', 'Fuel_Consumption_Comb(L/100 km)',
#        'Fuel_Consumption_Comb(mpg)', 'CO2_Emissions(g/km)'],
#       dtype='object')

# %% [markdown]
# Vemos que todos nuestros cambios se han hecho correctamente.

# %% [markdown]
# Ahora comprobaremos si hay valores nulos en nuestro dataframe.

# %%
base_nueva.isnull().any()
# Out:
# Make                               False
# Model                              False
# Vehicle_Class                      False
# Engine_Size(L)                     False
# Cylinders                          False
# Transmission                       False
# Fuel_Type                          False
# Fuel_Consumption_City(L/100 km)    False
# Fuel_Consumption_Hwy(L/100 km)     False
# Fuel_Consumption_Comb(L/100 km)    False
# Fuel_Consumption_Comb(mpg)         False
# CO2_Emissions(g/km)                False
# dtype: bool

# %% [markdown]
# Como vemos, no hay ningún valor nulo en todos nuestros datos esta es una buen señal para comenzar a realizar nuestras gráficas.

# %% [markdown]
# ## Gráfica de barras

# %%
base_nueva['Engine_Size(L)'].value_counts().head(10).plot.bar()

# %% [markdown]
# Gráfica de barras de los 10 elementos con más repeticiones de la columna "Engine_Size(L)" que nos indica en el eje y las repeticiones de este elemento y en el eje x el número de litros con el que el automóvil se encuentra con sus cilindros llenos.

# %% [markdown]
# ## Gráfica de barras con proporción

# %%
(base_nueva['Cylinders'].value_counts().head(10)/len(base_nueva)).plot.bar()

# %% [markdown]
# Gráfica de barras con proporción de la columna "Cylinders" esta gráfica nos muestra en el eje x el número de cilindros que tiene el automóvil y en el eje y el porcentaje que ocupan del total.

# %% [markdown]
# ## Gráfica de barras

# %%
base_nueva['Fuel_Consumption_City(L/100 km)'].value_counts().sort_index().plot.bar()

# %% [markdown]
# En esta gráfica de barras observamos el consumo de combustible en la ciudad y se muestra en litros por cada 100 kilómetros (L / 100 km) ordenado desde el consumo más pequeño hasta el mayor. En esta ocasión dejamos todos los datos en el eje x para darnos una idea de la distribución de los datos.

# %% [markdown]
# ## Gráfica de líneas

# %%
base_nueva['Fuel_Consumption_Hwy(L/100 km)'].value_counts().sort_index().plot.line()

# %% [markdown]
# En esta gráfica de línea podemos ver los cambios en la frecuencia del consumo de combustible en la autopista y se muestra en litros por cada 100 kilómetros (L / 100 km).

# %%
base_nueva['Fuel_Consumption_Hwy(L/100 km)'].value_counts().sort_index().plot.area()

# %% [markdown]
# La gráfica anteriormente mostrada es la misma de arriba solo que con su area rellena.

# %% [markdown]
# ## Histogramas

# %%
base_nueva[base_nueva['Fuel_Consumption_Comb(L/100 km)'] < 20]['Fuel_Consumption_Comb(L/100 km)'].plot.hist()

# %% [markdown]
# Este histograma muestra las frecuencias de los automóviles que consumen menos de 20 L/100 km de combustible combinado.

# %%
base_nueva['Fuel_Consumption_Comb(mpg)'].plot.hist()

# %% [markdown]
# En este histograma vemos la frecuencia de los automóviles y su consumo de combustible combinado en millas por galón (mpg).

# %% [markdown]
# ## Gráficas bi variantes

# %%
base_nueva.sample(10).plot.scatter(x='Make', y='CO2_Emissions(g/km)')

# %% [markdown]
# Emisiones de una muestra de 10 datos de CO2 por marca de automóvil.

# %%
base_nueva.plot.hexbin(x='Cylinders', y='CO2_Emissions(g/km)', gridsize=15)

# %% [markdown]
# En la gráfica vemos las frecuencias de emisiones de CO2 por cada tipo de cilindros.

# %%
base_nueva.plot.hexbin(x='Cylinders', y='CO2_Emissions(g/km)', gridsize=5)

# %% [markdown]
# En la gráfica vemos las frecuencias de emisiones de CO2 por cada tipo de cilindros pero en una escala mayor.

# %% [markdown]
# ## Stacked plots

# %%
base_nueva.head(10).plot.bar(stacked=True)

# %% [markdown]
# Información completa en barras de los primeros 10 registros de nuestra base de datos.

# %%
base_nueva.head(10).plot.area()

# %% [markdown]
# Información completa en gráfica rellena de los primeros 10 registros de nuestra base de datos.

# %%
base_nueva.head(10).plot.line()

# %% [markdown]
# Información completa en gráfica de línea de los primeros 10 registros de nuestra base de datos. Como vemos esta gráfica no nos es muy útil ya que las columnas que tienen su valor en L/100 Km quedan muy juntas y no se aprecian muy bien.

# %% [markdown]
# ##  Gráficas de barras con librería seaborn

# %%
sns.countplot(base_nueva['Cylinders'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# En nuestra gráfica anterior vemos cuantos carros hay por cada tipo de automóvil con cierto número de cilindros.

# %% [markdown]
# ## Gráficas KDE

# %%
sns.kdeplot(base_nueva.query('Cylinders < 6').Cylinders)

# %%
base_nueva[base_nueva['Cylinders'] < 6]['Cylinders'].value_counts().sort_index().plot.line()

# %% [markdown]
# Como vemos la diferencia entre la gráfica KDE que es la primera y la segunda que es de tipo línea es muy notoria ya que la KDE nos ayuda a visualizar de una forma más amigable la distribución de los datos que tienen los automóviles con menos de 8 cilindros.

# %%
from seaborn import kdeplot
kdeplot(base_nueva['Cylinders'], base_nueva['CO2_Emissions(g/km)'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# En esta gráfica vemos la concentración de las emisiones de CO2 para todos los tipos de cilindros.

# %% [markdown]
# ## Gráficas de distancias

# %%
sns.distplot(base_nueva['Engine_Size(L)'], bins=10, kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Esta gráfica de dsitancia sirve igual que un histograma y nos muestra la distribución del tamaño de los motores de los autos de nuestra base en litros (L).

# %% [markdown]
# ## Jointplots

# %%
sns.jointplot( x='Cylinders',y='CO2_Emissions(g/km)', data=base_nueva)

# %% [markdown]
# Este jointplot nos dice la concentración en puntos de emisiones de CO2 por cada tipo de cilindros y en el contorno de la gráfica se muestra un gráfico de barras que indica la misma información que se encuentra dentro de esta grágica solo que nos la muestra con barras.

# %%
sns.jointplot(x='Cylinders',y='CO2_Emissions(g/km)', data=base_nueva, kind='hex', 
              gridsize=20)

# %% [markdown]
# Esta gráfica nos muestra lo mismo que la anterior solo que con hexagonos de colores que nos dicen la concentración de datos.

# %% [markdown]
# ## Box plots

# %%
df = base_nueva[base_nueva.Cylinders.isin(base_nueva.Cylinders.value_counts().head(5).index)]

sns.boxplot(
    x='Cylinders',
    y='CO2_Emissions(g/km)',
    data=df
)

# %% [markdown]
# El boxplot nos muestra el mínimo, máximo, promedio y cuartiles de los primeros 5 tipos de cilinros que son los de 3, 4, 6, 8 y 12 cilindros.

# %% [markdown]
# ## Gráfica de violín

# %%
sns.violinplot(
    x='Make',
    y='CO2_Emissions(g/km)',
    data=base_nueva[base_nueva.Make.isin(base_nueva.Make.value_counts()[:5].index)]
)

# %% [markdown]
# La gráfica de violín nos muestra la frecuencia, el rango intercuartílico y la mediana de las emisiones de CO2 de las últimas 5 marcas de carros.

# %%
sns.pairplot(base_nueva[['Cylinders', 'Engine_Size(L)', 'CO2_Emissions(g/km)']])

# %% [markdown]
# En esta matriz vemos la correlación entre cada una de las columnas de cilindros, emisión de CO2 y de tamaño del motor.

# %% [markdown]
# ## Gráficas multi variantes

# %%
sns.lmplot(x='Engine_Size(L)', y='CO2_Emissions(g/km)', hue='Cylinders',  data=base_nueva.loc[base_nueva['Cylinders'].isin([3,4,5])],  fit_reg=False)

# %% [markdown]
# En la gráfica anterior podemos observar las emisiones de CO2 de cada tipo de tamaño de motor agrupado por cilindros, solo mostramos los carros con 3, 4 y 5 cilindros.

# %% [markdown]
# Para la gráfica de doble histograma y para el box plot  multi variado ocupamos variables binarias así que para este paso convertiremos mediante un ciclo nuestra columna llamda "Transimisión", esta columna maneja varios tipos de autos automáticos y manuales, para nuestra convenencia la dejaremos solo en 2 valores: Automatic y Manual.

# %%
i=0
for i in range(0,7385):     # Gracias a que ya sabemos el tamaño de la base de datos
    if base_nueva['Transmission'][i][0]=='A':
        base_nueva['Transmission'][i]='Automatic'
    if base_nueva['Transmission'][i][0]=='M':
        base_nueva['Transmission'][i]='Manual'
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Comprobamos que el cambio se haya hecho correctamente.

# %%
base_nueva['Transmission'].unique()
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %% [markdown]
# Vemos que sí se realizó bien el cambio de los valores únicos en esa columna.
# Por último cambiaremos el nombre de la columna de emisiones de CO2 y la columna del tamaño del motor, ya que nos causa problemas con la sintáxis del código al tenner estas columnas parentésis en sus nombres.

# %%
base_nueva = base_nueva.rename(columns = {'CO2_Emissions(g/km)':'CO2_Emissions','Engine_Size(L)':'Engine_Size'})

# %%
A = plt.hist(base_nueva[base_nueva["Transmission"] == "Automatic"].CO2_Emissions,bins=30,fc = (1,0,0,0.5),label = "Automático")
M = plt.hist(base_nueva[base_nueva["Transmission"] == "Manual"].CO2_Emissions,bins=30,fc = (0,1,0,0.5),label = "Manual")
plt.legend()
plt.xlabel("Emisión de CO2")
plt.ylabel("Frecuencia")
plt.title("Histograma")
plt.show()

# %% [markdown]
# Este tipo de gráfico nos ayuda a ver los histogramas de las emisiones de CO2 de ambos tipos de transmisión.

# %%
Z = plt.hist(base_nueva[base_nueva["Fuel_Type"] == "Z"].Engine_Size,bins=30,label = "Tipo 'Z'")
D = plt.hist(base_nueva[base_nueva["Fuel_Type"] == "D"].Engine_Size,bins=30,label = "Tipo 'D'")
X = plt.hist(base_nueva[base_nueva["Fuel_Type"] == "X"].Engine_Size,bins=30,label = "Tipo 'X'")
E = plt.hist(base_nueva[base_nueva["Fuel_Type"] == "E"].Engine_Size,bins=30,label = "Tipo 'E'")
N = plt.hist(base_nueva[base_nueva["Fuel_Type"] == "N"].Engine_Size,bins=30,label = "Tipo 'N'")
plt.legend()
plt.xlabel("Tipo de gasolinas")
plt.ylabel("Frecuencia")
plt.title("Histograma")
plt.show()

# %% [markdown]
# En este otro vemos los histogramas de los tamaños de motor para los dideferentes tipos de combustibles.

# %% [markdown]
# En esta gráfica vemos los histogramas de cada tipo de transmisión en

# %%
mdata = pd.melt(base_nueva,id_vars = "Transmission",value_vars = ['CO2_Emissions'])
plt.figure(figsize = (10,10))
sns.boxplot(x=base_nueva['Transmission'], y=base_nueva['CO2_Emissions'], hue='Transmission',data= mdata)
plt.show()

# %% [markdown]
# En este boxplot dividido por tipo de transmisión vemos las emisiones de dióxido de carbono por cada tipo de transmision ya sea automática o manual.

# %%
f,ax=plt.subplots(figsize = (7,7))
sns.heatmap(base_nueva.corr(),annot= True,linewidths=0.5,fmt = ".1f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Mapa de correlación')
plt.show()

# %% [markdown]
# En este mapa vemos que tanto se relacionan las variables entre ellas mismas.

# %% [markdown]
# ## Gráfica puntos extras

# %%
Queremos hacer una gráfica de pastel, así que primero tendremos que agrupar por clase de vehículo y sumar sus emisiones de CO2.

# %%
cols= ['Vehicle_Class']
base_2= base_nueva.groupby(cols)
base_nueva_2=base_2[['CO2_Emissions']].sum()
base_nueva_2
# Out:
#                           CO2_Emissions
# Vehicle_Class
# COMPACT                          221446
# FULL-SIZE                        168259
# MID-SIZE                         252042
# MINICOMPACT                       77134
# MINIVAN                           20985
# PICKUP TRUCK - SMALL              44356
# PICKUP TRUCK - STANDARD          162214
# SPECIAL PURPOSE VEHICLE           18295
# STATION WAGON - MID-SIZE          12651
# STATION WAGON - SMALL             50417
# SUBCOMPACT                       149348
# SUV - SMALL                      287568
# SUV - STANDARD                   224055
# TWO-SEATER                       127629
# VAN - CARGO                        7953
# VAN - PASSENGER                   26216

# %%
clases = ['COMPACT', 'FULL-SIZE', 'MID-SIZE', 'MINICOMPACT', 'PICKUP TRUCK-SMALL', 'PICKUP TRUCK-STANDARD',
         'STATION WAGON-SMALL', 'SUBCOMPACT', 'SUV-SMALL', 'SUV-STANDARD',
         'TWO-SEATER', 'VAN-PASSENGER',  'SPECIAL PURPOSE VEHICLE', 'MINIVAN']
suma = [221446, 168259, 252042, 77134, 44356, 162214, 50417, 149348, 287568, 224055, 127629, 26216,  18295, 20985]

# %% [markdown]
# Con el proceso anterior podemos crear el gráfico.

# %%
plt.pie(suma, labels=clases)
plt.axis("equal")
plt.show()

# %% [markdown]
# A partir de esta gráfica podemos conocer la distribución que se tiene cuando se habla del total de los gases de CO2 emitidos por clase de automóvil. Resaltando las aportaciones de 'SUV-SMALL', 'SUV-STANDARD', 'MID-SIZE' y 'COMPACT'.

# %% [markdown]
# # MOVIES DATASET FOR FEATURE EXTRACION

# %% [markdown]
# **1) Título de la base de datos**
#
# a) Nombre con el que se encuentra en la página: "MOVIES DATASET FOR FEATURE EXTRACION ,PREDICTION"
#
# b) Url de la página:  [MOVIES DATASET](https://www.kaggle.com/bharatnatrayn/movies-dataset-for-feature-extracion-prediction)

# %% [markdown]
# #**PRÁCTICA DE VISUALIZACIÓN DE DATOS**

# %% [markdown]
# Ya habiamos importado la librería, asi que visualizamos la base.

# %%
basemovies = pd.read_csv('movies.csv', sep=',')
basemovies
# Out:
#                                    MOVIES         YEAR  ... RunTime  Gross
# 0                           Blood Red Sky       (2021)  ...   121.0    NaN
# 1     Masters of the Universe: Revelation     (2021– )  ...    25.0    NaN
# 2                        The Walking Dead  (2010–2022)  ...    44.0    NaN
# 3                          Rick and Morty     (2013– )  ...    23.0    NaN
# 4                         Army of Thieves       (2021)  ...     NaN    NaN
# ...                                   ...          ...  ...     ...    ...
# 9994                       The Imperfects     (2021– )  ...     NaN    NaN
# 9995                               Arcane     (2021– )  ...     NaN    NaN
# 9996                    Heart of Invictus     (2022– )  ...     NaN    NaN
# 9997                       The Imperfects     (2021– )  ...     NaN    NaN
# 9998                       The Imperfects     (2021– )  ...     NaN    NaN
#
# [9999 rows x 9 columns]

# %% [markdown]
# Como vemos en la impresión anterior nuestro dataframe tiene 9999 filas y 9 columnas.

# %% [markdown]
# Como tienen datos nulos, lo que vamos a hacer para poder realizar la visualización de los datos es que se lo vamos a quitar.

# %%
bm= basemovies.dropna() # elimina los elementos nulos
bm
# Out:
#                                                  MOVIES  ...     Gross
# 77                               The Hitman's Bodyguard  ...   $75.47M
# 85                                        Jurassic Park  ...  $402.45M
# 95                                        Don't Breathe  ...   $89.22M
# 111   The Lord of the Rings: The Fellowship of the Ring  ...  $315.54M
# 125                                         Escape Room  ...   $57.01M
# ...                                                 ...  ...       ...
# 5750                           Vidal Sassoon: The Movie  ...    $0.09M
# 5770                                       Men at Lunch  ...    $0.00M
# 5835                                    Decoding Deepak  ...    $0.01M
# 6056                                     Theo Who Lived  ...    $0.01M
# 6292                                   Southern Justice  ...    $0.14M
#
# [460 rows x 9 columns]

# %% [markdown]
# Como observamos en la anterior impresión, ya no tenemos datos nulos en nuestra base de datos.

# %% [markdown]
# Y ahora sí comenzamos a revisar los nombres de las columnas:

# %%
bm.columns
# Out:
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES',
#        'RunTime', 'Gross'],
#       dtype='object')

# %% [markdown]
# Ahora checaremos  el tipo de dato que tiene cada columna ya que nos interesa saber con cuales columnas podemos hacer un análisis estadístico básico.

# %%
bm.dtypes
# Out:
# MOVIES       object
# YEAR         object
# GENRE        object
# RATING      float64
# ONE-LINE     object
# STARS        object
# VOTES        object
# RunTime     float64
# Gross        object
# dtype: object

# %% [markdown]
# Como vemos en la impresión anterior, las columnas: "MOVIES", "YEAR", "GENRE", "ONE-LINE", "STARS", "VOTES" y "GROSS" no son de tipo numérico ya sea "int" o sea entero o "float" que son los flotantes, así que no se puede revisar la información estadística básica de estas columnas.

# %% [markdown]
# # **INFORMACIÓN ESTADÍSTICA BÁSICA**

# %% [markdown]
# ##Columna "RATING":
#
# ##Representa la puntuación que las personas le dieron a la película o serie.

# %%
bm['RATING'].sum()
# Out:
# 3053.5

# %% [markdown]
# La suma de todos los elementos de la columna "RATING" es 3053.5

# %%
bm['RATING'].mean()
# Out:
# 6.638043478260876

# %% [markdown]
# El promedio de todos los elementos de la columna "RATING" es 6.6380

# %%
bm['RATING'].cumsum()
# Out:
# 77         6.9
# 85        15.0
# 95        22.1
# 111       30.9
# 125       37.3
#          ...
# 5750    3031.8
# 5770    3038.1
# 5835    3043.6
# 6056    3050.4
# 6292    3053.5
# Name: RATING, Length: 460, dtype: float64

# %% [markdown]
# Acumulados de la columna fila por fila.

# %%
bm['RATING'].describe() # Resumen estadístico de la columna.
# Out:
# count    460.000000
# mean       6.638043
# std        0.940894
# min        3.100000
# 25%        6.100000
# 50%        6.600000
# 75%        7.300000
# max        8.900000
# Name: RATING, dtype: float64

# %% [markdown]
# Resumen estadístico de la columna "RATING", en éste se muestran distintos datos como: la media, desviación estándar, mínimo. máximo y sus cuartiles.

# %%
bm['RATING'].count() # Cuantos elementos no nulos hay en la columna.
# Out:
# 460

# %% [markdown]
# Como vemos tenemos 460 elementos no nulos y nuestra base de datos tiene 460 filas así que no nos hace falta ningún dato de esta columna.

# %%
bm['RATING'].min() # min de una columna.
# Out:
# 3.1

# %% [markdown]
# El valor más pequeño de la columna es 3.1

# %%
bm['RATING'].max() # máximo de una columna.
# Out:
# 8.9

# %% [markdown]
# El valor más grande de la columna es 8.9

# %%
bm['RATING'].median()
# Out:
# 6.6

# %% [markdown]
# La mediana de la columna es 6.6

# %%
bm['RATING'].var()
# Out:
# 0.8852815667329711

# %% [markdown]
# La varianza de esta columna es 0.8852

# %%
bm['RATING'].std()
# Out:
# 0.9408940252403408

# %% [markdown]
# La desviación estándar de la columna es 0.94089

# %%
bm['RATING'].skew() # Valor de asimetría en los datos.
# Out:
# -0.47324228171020244

# %% [markdown]
# Ya que este número es menor a cero se dice que se tiene una forma en su distribución de probabilidad "platicúrtica".

# %% [markdown]
# ##Columna "RUNTIME":
#
# ##Representa el número entero de minutos que dura la película o serie.

# %%
bm['RunTime'].sum()
# Out:
# 48961.0

# %% [markdown]
# La suma de todos los elementos de la columna "RunTime" es 48961.0

# %%
bm['RunTime'].mean()
# Out:
# 106.43695652173913

# %% [markdown]
# El promedio de todos los elementos de la columna "RunTime" es 106.4369

# %%
bm['RunTime'].cumsum()
# Out:
# 77        118.0
# 85        245.0
# 95        333.0
# 111       511.0
# 125       610.0
#          ...
# 5750    48621.0
# 5770    48696.0
# 5835    48779.0
# 6056    48865.0
# 6292    48961.0
# Name: RunTime, Length: 460, dtype: float64

# %% [markdown]
# Acumulados de la columna fila por fila.

# %%
bm['RunTime'].describe()
# Out:
# count    460.000000
# mean     106.436957
# std       21.380930
# min       24.000000
# 25%       93.000000
# 50%      103.000000
# 75%      116.000000
# max      228.000000
# Name: RunTime, dtype: float64

# %% [markdown]
# Resumen estadístico de la columna "RunTime", en éste se muestran distintos datos como: la media, desviación estándar, mínimo. máximo y sus cuartiles.

# %%
bm['RunTime'].count()
# Out:
# 460

# %% [markdown]
# Como vemos tenemos 460 elementos no nulos y nuestra base de datos tiene 460 filas así que no nos hace falta ningún dato de esta columna.

# %%
bm['RunTime'].min()
# Out:
# 24.0

# %% [markdown]
# El valor más pequeño de la columna es 24

# %%
bm['RunTime'].max()
# Out:
# 228.0

# %% [markdown]
# El valor más grande de la columna es 228

# %%
bm['RunTime'].median()
# Out:
# 103.0

# %% [markdown]
# La mediana de la columna es 103

# %%
bm['RunTime'].var()
# Out:
# 457.1441650089988

# %% [markdown]
# La varianza de esta columna es 457.1441

# %%
bm['RunTime'].std()
# Out:
# 21.380929937890887

# %% [markdown]
# La desviación estándar de la columna es 21.3809

# %%
bm['RunTime'].skew()
# Out:
# 1.4973427450773038

# %% [markdown]
# #**CORRELACIÓN Y COVARIANZA DE LOS DATOS**

# %%
print('Correlacion de los datos')
print(bm.corr())
# Out:
# Correlacion de los datos
#            RATING   RunTime
# RATING   1.000000  0.312683
# RunTime  0.312683  1.000000

# %%
print('Covarianza de los datos')
print(bm.cov())
# Out:
# Covarianza de los datos
#            RATING     RunTime
# RATING   0.885282    6.290312
# RunTime  6.290312  457.144165

# %% [markdown]
# Como vemos en lo anterior mostrado la matriz de correlación tiene su diagonal principal llena de unos como es de esperarse.

# %% [markdown]
# #**GRÁFICAS**

# %% [markdown]
# Comenzaremos revisando los nombres de las columnas.

# %%
bm.columns
# Out:
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'ONE-LINE', 'STARS', 'VOTES',
#        'RunTime', 'Gross'],
#       dtype='object')

# %% [markdown]
# Los nombres de las columnas son los elementos que se han impreso. Podemos notar a simple vista que estos elementos están en inglés.
#
# Algunos de estos nombres no son lo suficientemente entendibles  para hacer referencia a los elementos que contiene la columna.
#
# Por esto último, se opta por cambiar los nombres de algunas columnas, con el fin de facilitar el manejo de los datos

# %%
# se crea nueva base con las modificaciones de los nombres de columnas
bmn = bm.rename(columns = {'Gross':'GANANCIA', 'ONE-LINE':'DESCRIPCION'})

# %% [markdown]
# Corroboramos que el cambio se haya realizado:

# %% [markdown]
# Vemos que todos nuestros cambios se han hecho correctamente.

# %%
bmn.columns
# Out:
# Index(['MOVIES', 'YEAR', 'GENRE', 'RATING', 'DESCRIPCION', 'STARS', 'VOTES',
#        'RunTime', 'GANANCIA'],
#       dtype='object')

# %% [markdown]
# Ahora comprobaremos si hay valores nulos en nuestro dataframe.

# %%
bmn.isnull().any()
# Out:
# MOVIES         False
# YEAR           False
# GENRE          False
# RATING         False
# DESCRIPCION    False
# STARS          False
# VOTES          False
# RunTime        False
# GANANCIA       False
# dtype: bool

# %% [markdown]
# Como vemos, no hay ningún valor nulo en todos nuestros datos esta es una buen señal para comenzar a realizar nuestras gráficas.

# %% [markdown]
# ## Gráfica de barras

# %%
bmn['RATING'].value_counts().head(10).plot.bar()

# %% [markdown]
# Gráfica de barras de los 10 elementos con más repeticiones de la columna "RATING" que nos indica en el eje y las repeticiones de este elemento y en el eje x representa la puntuación obtenida.

# %% [markdown]
# ## Gráfica de barras con proporción

# %%
(bmn['GANANCIA'].value_counts().head(10)/len(bmn)).plot.bar()

# %% [markdown]
# Gráfica de barras con proporción de la columna "GANANCIA",esta gráfica nos muestra en el eje x la ganancia en millón de dólares y en el eje y el porcentaje que ocupan del total.

# %% [markdown]
# ## Gráfica de barras

# %%
bmn['RunTime'].value_counts().sort_index().plot.bar()

# %% [markdown]
# En esta gráfica de barras observamos el número entero de minutos que duran la película o serie.

# %% [markdown]
# ## Gráfica de líneas

# %%
bmn['RATING'].value_counts().sort_index().plot.line()

# %%
bmn['RATING'].value_counts().sort_index().plot.area()

# %% [markdown]
# En estas gráficas podemos ver los cambios en la frecuencia de la puntuación que es puesta por el público. La segunda es igual a la primera solo que el área esta sombreada.

# %% [markdown]
# ## Histogramas

# %%
bmn[bmn['RunTime'] < 120]['RunTime'].plot.hist()

# %% [markdown]
# Este histograma muestra las frecuencias de las películas o series que su duración es menor a 120 minutos.

# %%
bmn['RATING'].plot.hist()

# %% [markdown]
# En este histograma vemos la frecuencia de la puntuación que obtubieron las películas o series.

# %% [markdown]
# ## Gráficas bi variantes

# %%
bmn.sample(10).plot.scatter(x='MOVIES', y='RATING')

# %% [markdown]
# Puntuación de una muestra de 10 películas/series.

# %%
bmn.plot.hexbin(x='RATING', y='RunTime', gridsize=15)

# %% [markdown]
# En la gráfica vemos las frecuencias de la duración en minutos por cada tipo de puntuación.

# %%
bmn.plot.hexbin(x='RATING', y='RunTime', gridsize=5)

# %% [markdown]
# En la gráfica vemos las frecuencias de la duración por cada tipo de puntuación pero en una escala mayor.

# %% [markdown]
# ## Stacked plots

# %%
bmn.head(10).plot.bar(stacked=True)

# %% [markdown]
# Información completa en barras de los primeros 10 registros de nuestra base de datos.

# %%
bmn.head(10).plot.area()

# %% [markdown]
# Información completa en gráfica rellena de los primeros 10 registros de nuestra base de datos.

# %%
bmn.head(10).plot.line()

# %% [markdown]
# Información completa en gráfica de línea de los primeros 10 registros de nuestra base de datos.

# %% [markdown]
# ##  Gráficas de barras con librería seaborn

# %%
x=bmn.sample(150)
sns.countplot(x['RunTime'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# En nuestra gráfica anterior vemos de una muestra de 8 elementos, cuantas películas/series hay por cada tipo de duración en minutos.

# %% [markdown]
# ## Gráficas KDE

# %%
sns.kdeplot(bmn.query('RATING > 5').RATING)

# %%
bmn[bmn['RATING'] > 5]['RATING'].value_counts().sort_index().plot.line()

# %% [markdown]
# Como vemos la diferencia entre la gráfica KDE que es la primera y la segunda que es de tipo línea es muy notoria ya que la KDE nos ayuda a visualizar de una forma más amigable la distribución de los datos que tienen las películas/series con más de 5 en puntuación.

# %%
from seaborn import kdeplot
kdeplot(bmn.RunTime, bmn.RATING)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Este tipo de gráfico nos ayuda a ver la distribución de la puntuación y la duración de las películas y series.

# %% [markdown]
# ## Gráficas de distancias

# %%
sns.distplot(bmn['RunTime'], bins=10, kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Esta gráfica de distancia sirve igual que un histograma y nos muestra la distribución de la duración en minutos de las películas/series.

# %% [markdown]
# ## Jointplots

# %%
sns.jointplot( x='RATING',y='RunTime', data=bmn)

# %%
sns.jointplot(x='RATING',y='RunTime', data=bmn, kind='hex', 
              gridsize=20)

# %% [markdown]
# Las dos gráficas son muy similares ya que muestran la dispersión de los datos, solo que en diferente forma, la primera la muestra a través de puntos en el plano y la segunda mediante tonalidades de colores siendo la tonalidad más oscura la de mayor frecuencia. En este tipo de gráficas nos ayuda a observar la dispersón y la frecuencia de la duración de las películas/series y la puntuación asignada, la ventaja de estos es que también muestra el histograma de cada variable.

# %% [markdown]
# ## Box plots

# %%
df = bmn[bmn.RATING.isin(bmn.RATING.value_counts().head(5).index)]

sns.boxplot(
    x='RATING',
    y='RunTime',
    data=df
)

# %% [markdown]
# El boxplot nos muestra el mínimo, máximo, promedio y cuartiles de los primeros 5 tipos de puntuación que son 6.3, 6.4, 6.5, 7.1 y 7.3.

# %% [markdown]
# ## Gráfica de violín

# %%
sns.violinplot(
    x='MOVIES',
    y='RATING',
    data=bmn[bmn.MOVIES.isin(bmn.MOVIES.value_counts()[:3].index)]
)

# %% [markdown]
# Está gráfica se utiliza para visualizar  la distribución de los datos y su densidad de probabilidad, es una combinación de un diagrama de caja y bigotes y un diagrama de denisad  solo que los diagramas de violín incluyen más información como saber si una distribución es bimodal o multimodal. Por lo tanto, en este gráfico podemos sacar la mediana, el rango intercuartílico y la frecuencia de la puntuación por película/serie.

# %%
sns.pairplot(bmn[['RunTime', 'RATING']])

# %% [markdown]
# En esta matriz vemos la correlación entre cada una de las puntuaciones y la duración de las películas/series.

# %% [markdown]
# ## Gráficas multi variantes

# %% [markdown]
# Como la base de datos Movies, solo tiene dos variables flotantes no se puede realizar las gráficas multi variantes.
