# %% [markdown]
# # Equipo 1
# ## Grupo: 001 (Lunes 7:00 - 10:00 pm)
# ### Integrantes:
# + 1848655 - Rangel Vallejo Isabel Alejandra
# + 1851167 - Aguilar Sánchez José Antonio
# + 1851124 - Cerecero Peña Angela Scarlett
# + 1851528 - Romero Banda José Manuel
# + 1853849 - García Gutiérrez Alfonso de Jesús

# %% [markdown]
# ##PÓSTER: CONTAMINACIÓN POR AUTOMÓVILES

# %% [markdown]
# # CO2 Emission by Vehicles

# %% [markdown]
# **1) Título de la base de datos**
# a) Nombre con el que se encuentra en la página: **"CO2 Emission by Vehicles"**
# b) Url de la página: [CO2 Emission](https://www.kaggle.com/debajyotipodder/co2-emission-by-vehicles)

# %% [markdown]
# **2) Introducción general**

# %% [markdown]
# El CO2 (dióxido de carbono) es un compuesto de carbono y oxígeno que existe como gas incoloro en condiciones de temperatura y presión estándar. Es uno de los gases que conforman al efecto invernadero, las principales consecuencias del efecto invernadero son: aumento de la temperatura media de la Tierra, reducción de la superficie de glaciares y, como consecuencia, elevación del nivel del agua de los mares y océanos. Las emisiones excesivas de este gas son una de las principales causas del calentamiento global. Un problema causado por la actividad humana y empeorado por la larga pervivencia del CO2 en la atmósfera.
#
# Los automóviles particulares generan el 18% de las emisiones de CO2. Una herramienta capaz de cuantificar los datos relevantes a las emisiones de CO2 producidas por automóviles ayudaría en gran medida a la humanidad a poder combatir este fenómeno que está agravando cada vez más la situación global. La difusión de esta información resultará interesante a los lectores debido a que es un tema que compete a la mayor parte del mundo.

# %% [markdown]
# **3) Descripción de los datos**

# %% [markdown]
# Los datos que se obtuvieron se recopilaron a partir de una tabla que señala las distintas características que pudieran contribuir a las emisiones de CO2 hechas por automóviles. La tabla muestra la información de manera completa.

# %% [markdown]
# La tabla consta de 12 columnas, estas son:
# + **Make** - Marca del vehículo (ejemplo: ACURA, ASTON MARTIN, etc.).
# + **Modelo** - Modelo del automóvil (ejemplo: ILX, V8 VANTAGE, etc.).
# + **Vehicle Class** - Clase del vehículo (ejemplo: COMPACT, MINIVAN, etc.).
# + **Engine Size(L)** - Tamaño del motor del automóvil, viene representado en litros e indican la cantidad de gasolina que utiliza un coche cuando sus cilindros están llenos.
# + **Cylinders** - Cantidad de cilindros que tiene el vehículo.
# + **Transmission** - Tipo de transmisión del automóvil. Se clasifica en:
#     + A = Automático
#     + AM = Automated manual
#     + AS = Automatic with select shift
#     + AV = Continuously variable
#     + M = Manual
# + **Fuel Type** - Tipo de gasolina que usa el vehículo. Las cuales son:
#     + X = Gasolina Regular
#     + Z = Gasolina Premium
#     + D = Diesel
#     + E = Etanol (E85)
#     + N =Gas natural
#     + Número de marchas del automóvil:  de 3 a 10.
# + **Fuel Consumption City (L/100 km)** -  Consumo de combustible en la ciudad; se muestra en litros por cada 100 kilómetros (L / 100 km).
# + **Fuel Consumption Hwy (L/100 km)** - Consumo de combustible en la autopista; se muestra en litros por cada 100 kilómetros (L / 100 km).
# + **Fuel Consumption Comb (L/100 km)** - Consumo de combustible combinada (55% en la ciudad y 45% en la carretera); se muestra en litros por cada 100 kilómetros (L / 100 km).
# + **Fuel Consumption Comb (mpg)** - Consumo de combustible combinada (55% en la ciudad y 45% en la carretera); se muestra en millas por galón (mpg)
# + **CO2 Emissions(g/km)** - Emisiones de dióxido de carbono del tubo de escape (en gramos por kilómetro) de una conducción combinada en ciudad y carretera.

# %% [markdown]
# **4) Justificación del uso de datos**

# %% [markdown]
# Como se mencionó anteriormente, el calentamiento global es detonado por las emisiones de CO2, que a su vez, son provocadas por las actividades humanas; se sabe que los automóviles son responsables de esto en un 18%. Teniendo en cuenta esto, la base de datos es una herramienta completa que brinda información para estudiar dicho problema debido a que se puede identificar las cualidades, patrones o características que un vehículo debe poseer para emitir cierto nivel de CO2.
#
# Con el uso de estos datos se podría analizar si el rendimiento que un automóvil tiene (en ciudad o carretera) contribuye a este problema, así como también estudiar los distintos grupos de transmisión con el fin de encontrar algún patrón aparente que nos indique el comportamiento del vehículo en relación a su contribución de CO2. Con todo esto, podemos concluir que la motivación de trabajar con estos datos son los distintos objetivos y preguntas de interés que se pueden plantear y trabajar con facilidad. De la misma manera, los resultados arrojados por la investigación serán atrayentes para la mayoría de las personas, lo que implica un impulso extra de interés al trabajar con esta base.

# %% [markdown]
# **5) Objetivo final**

# %% [markdown]
# Objetivo principal:
# + Predecir las emisiones de CO2 (g/km) de los automóviles

# %% [markdown]
# Objetivos secundarios:
# + Establecer si el tipo de gasolina influye en las emisiones producidas
# + Determinar las armadoras que tienen menor índice de emisiones

# %% [markdown]
# **6) Mencionar preguntas de interés**
# + ¿Qué clases de vehículo representan un mayor riesgo al ambiente?
# + ¿La transmisión del automóvil hace una diferencia al momento de emitir CO2?

# %% [markdown]
# ##Librerías a utilizar

# %% [markdown]
# Lo primero es llamar y nombrar a las librerías que se utilizarán a lo largo del trabajo, ya sea en la parte de análisis del modelo, revisión gráfica, limpieza de datos entre otras.

# %%
#Librerías para la limpieza de datos.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Para elaborar las gráficas
from matplotlib import style

# Para el proceso y modelado de la regresión
from scipy.stats import pearsonr
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.anova import anova_lm
from scipy import stats

# Configuración matplotlib
plt.rcParams['image.cmap'] = "bwr"
#plt.rcParams['figure.dpi'] = "100"
plt.rcParams['savefig.bbox'] = "tight"
style.use('ggplot') or plt.style.use('ggplot')

# Configuración warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Para esto, haremos uno de la libreria 'plotly', que deberemos instalarla desde nuestra terminar de anaconda con la siguiente instrucción:
# + conda install -c plotly plotly=5.3.1
#
# Al finalizar el proceso, solo basta con importar la libreria a utilizar.

# %%
import plotly.express as px

# %% [markdown]
# ## Limpieza de datos de la base principal: "CO2 Emission by Vehicles"

# %% [markdown]
# Continuaremos con la lectura de nuestra base de datos que previamente fue descargada de la página web mencionada anteriormente

# %%
baseCO2 = pd.read_csv('CO2.csv')

# %% [markdown]
# La base de datos está guardada en la variable "baseCO2"

# %% [markdown]
# ## Visualización

# %% [markdown]
# Una vez que la base se ha leído correctamente, se procede a analizar la estructura de la misma de manera completa

# %%
baseCO2
# Out:
#        Make        Model  ... Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0     ACURA          ILX  ...                          33                  196
# 1     ACURA          ILX  ...                          29                  221
# 2     ACURA   ILX HYBRID  ...                          48                  136
# 3     ACURA      MDX 4WD  ...                          25                  255
# 4     ACURA      RDX AWD  ...                          27                  244
# ...     ...          ...  ...                         ...                  ...
# 7380  VOLVO  XC40 T5 AWD  ...                          30                  219
# 7381  VOLVO  XC60 T5 AWD  ...                          29                  232
# 7382  VOLVO  XC60 T6 AWD  ...                          27                  240
# 7383  VOLVO  XC90 T5 AWD  ...                          29                  232
# 7384  VOLVO  XC90 T6 AWD  ...                          26                  248
#
# ...

# %% [markdown]
# Se puede observar que la base ha cargado y muestra algunos de los elementos que contiene

# %% [markdown]
# En ocasiones se desea ver algunos pocos elementos de la base y los nombres de la columna para empezar a estar familizarizados con la base, por lo que es muy útil emplear la función siguiente

# %%
baseCO2.head(2)
# Out:
#     Make Model  ... Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0  ACURA   ILX  ...                          33                  196
# 1  ACURA   ILX  ...                          29                  221
#
# [2 rows x 12 columns]

# %% [markdown]
# Así, podemos tener una idea de cómo está compuesta nuestra base

# %% [markdown]
# <div style="text-align: justify">Para tener organizada nuestra base, podemos ordenarla por alguna característica que nos sea relevante. En este caso, optaremos por ordenarla de acuerdo a la armadora, la cual es la columna "Make". Haciendo esto lograremos ordenar nuestros datos de A-Z.</div>

# %%
baseCO2 = baseCO2.sort_values('Make')
baseCO2
# Out:
#        Make             Model  ... Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0     ACURA               ILX  ...                          33                  196
# 4373  ACURA  MDX SH-AWD ELITE  ...                          26                  251
# 4372  ACURA        MDX SH-AWD  ...                          26                  259
# 4371  ACURA               ILX  ...                          34                  192
# 5454  ACURA               ILX  ...                          33                  199
# ...     ...               ...  ...                         ...                  ...
# 5442  VOLVO        S90 T6 AWD  ...                          30                  216
# 5441  VOLVO        S90 T5 AWD  ...                          32                  206
# 5440  VOLVO     S60 CC T5 AWD  ...                          30                  220
# 5438  VOLVO        S60 T6 AWD  ...                          30                  221
# ...

# %% [markdown]
# A simple vista pareciera haber quedado igual que como se tenía, sin embargo, no podemos estar seguros de eso, ya que no mostraba la base de manera completa. Haciendo esto nos aseguramos de que esté organizada.

# %% [markdown]
# ## Características de la base de datos

# %% [markdown]
# Con el objetivo de hacer un análisis profundo sobre la base, se estudiarán las características que esta tiene.
# Comenzaremos con el número de filas y columnas

# %%
baseCO2.shape
# Out:
# (7385, 12)

# %% [markdown]
# Tiene 7385 filas y 12 columnas. Se puede interpretar como una base de datos amplia, ya que tiene muchos elementos que la conforman

# %% [markdown]
# Ahora que sabemos la cantidad de filas y columnas que tiene nuestra base, podemos estudiar las características de las columnas a fondo, comenzando por el nombre de las mismas

# %%
baseCO2.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %% [markdown]
# ### Modificación de columnas

# %% [markdown]
# Los nombres de las columnas son los elementos que se han impreso. Podemos notar a simple vista que estos elementos están en inglés.

# %% [markdown]
# Algunos de estos nombres no son lo suficientemente claros para hacer referencia a los elementos que contiene cada columna, de la misma manera, algunos nombres tienen espacios entre palabras, lo que podría generar un problema al momento de querer referenciar elementos que pertenezcan a dicha columna.

# %% [markdown]
# Por esto último, se opta por cambiar los nombres de algunas columnas, con el fin de facilitar el manejo de los datos.

# %%
# se crea nueva base con las modificaciones de los nombres de columnas

base_nueva = baseCO2.rename(columns = {'Vehicle Class':'Vehicle_Class','Engine Size(L)':'Engine_Size(L)',
                                       'Fuel Type':'Fuel_Type','Fuel Consumption City (L/100 km)':'Fuel_Consumption_City(L/100 km)',
                                       'Fuel Consumption Hwy (L/100 km)':'Fuel_Consumption_Hwy(L/100 km)',
                                       'Fuel Consumption Comb(g/km)':'Fuel_Consumption_Comb(g/km)',
                                       'Fuel Consumption Comb (mpg)':'Fuel_Consumption_Comb(mpg)',
                                       'CO2 Emissions(g/km)':'CO2_Emissions(g/km)'})

# %% [markdown]
# Corroboramos que el cambio se haya realizado:

# %%
base_nueva.columns
# Out:
# Index(['Make', 'Model', 'Vehicle_Class', 'Engine_Size(L)', 'Cylinders',
#        'Transmission', 'Fuel_Type', 'Fuel_Consumption_City(L/100 km)',
#        'Fuel_Consumption_Hwy(L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel_Consumption_Comb(mpg)', 'CO2_Emissions(g/km)'],
#       dtype='object')

# %% [markdown]
# También, para mayor facilidad a la hora de utilizar los datos, tomaremos en cuenta solo dos grupos en la transmisión, la automática (A) y la manual (M), por lo que las diferentes transmisiones con inicial 'A' serán clasificados de manera general com transmision automática ('Automatic'), mismo caso para las transmisiones con inicial 'M', sólo que clasificadas como transmisión manual ('Manual'). Una de las razones principales para hacer esto, es el manejo de los datos, resulta más sencillo trabajar con sólo dos categorías que subdividirlas en más cuando no es tan necesario.

# %%
base_nueva['Transmission'].unique()
# Out:
# array(['AS5', 'AS9', 'AM8', 'AS6', 'AM7', 'AV7', 'AM9', 'AS10', 'M6',
#        'A8', 'AM6', 'A6', 'M7', 'AS8', 'AV8', 'AS7', 'A7', 'A9', 'AV',
#        'A10', 'M5', 'A4', 'A5', 'AV6', 'AV10', 'AS4', 'AM5'], dtype=object)

# %% [markdown]
# Estos son los distintos tipos de transmisión que se tienen. Los que comienzan con "A" serán los automáticos y los que comienzan con "M" los manuales. Esto se establece desde la descripción de los datos, por lo que es totalmente válido realizar esta acción.

# %% [markdown]
# Por medio del siguiente ciclo se busca transformar el valor de la variable transmisión. El ciclo busca en la primera letra de la transmisión y ejecuta de acuerdo a lo que queremos.

# %%
i=0
for i in range(0,7385):     # Gracias a que ya sabemos el tamaño de la base de datos
    if base_nueva['Transmission'][i][0]=='A':
        base_nueva['Transmission'][i]='Automatic'
    else:
        if base_nueva['Transmission'][i][0]=='M':
            base_nueva['Transmission'][i]='Manual'

# %% [markdown]
# Una vez terminada la sentencia, podemos corroborar que haya funcionado.

# %%
base_nueva['Transmission'].unique()
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %% [markdown]
# Sólo tenemos dos valores: Automático y Manual. Ha funcionado.
# Mostramos la nueva base.

# %%
base_nueva
# Out:
#        Make             Model  ... Fuel_Consumption_Comb(mpg)  CO2_Emissions(g/km)
# 0     ACURA               ILX  ...                         33                  196
# 4373  ACURA  MDX SH-AWD ELITE  ...                         26                  251
# 4372  ACURA        MDX SH-AWD  ...                         26                  259
# 4371  ACURA               ILX  ...                         34                  192
# 5454  ACURA               ILX  ...                         33                  199
# ...     ...               ...  ...                        ...                  ...
# 5442  VOLVO        S90 T6 AWD  ...                         30                  216
# 5441  VOLVO        S90 T5 AWD  ...                         32                  206
# 5440  VOLVO     S60 CC T5 AWD  ...                         30                  220
# 5438  VOLVO        S60 T6 AWD  ...                         30                  221
# ...

# %% [markdown]
# Vemos que todos nuestros cambios se han hecho correctamente

# %% [markdown]
# Otro problema que se pudiera presentar es en los tipos de datos. Necesitamos ver que nuestros datos estén guardados correctamente. Es decir, si son números, que sean valores numéricos y no de texto, entre otros. Para esto utilizamos la función dtypes

# %%
base_nueva.dtypes
# Out:
# Make                                 object
# Model                                object
# Vehicle_Class                        object
# Engine_Size(L)                      float64
# Cylinders                             int64
# Transmission                         object
# Fuel_Type                            object
# Fuel_Consumption_City(L/100 km)     float64
# Fuel_Consumption_Hwy(L/100 km)      float64
# Fuel Consumption Comb (L/100 km)    float64
# Fuel_Consumption_Comb(mpg)            int64
# CO2_Emissions(g/km)                   int64
# dtype: object

# %% [markdown]
# Vemos que el nombre de las armadoras, los modelos, las clases de vehículos, transmisiones y el tipo de gasolina son de tipo objeto, lo cual es bueno, ya que estos elementos son string que nos ayudan a categorizar, los cuales no presentan problema. Ahora bien, el tamaño del motor y los consumos de gasolina están dados como flotantes, lo que de nueva cuenta no representa inconveniente alguno. Por último, los cilindros y las emisiones de C02 son valores enteros, lo cual también está bien para nuestro análisis.

# %% [markdown]
# Podemos concluir finalmente que nuestros datos no presentan problemas con su tipo de datos.

# %% [markdown]
# #### Continuando con las características de las columnas...

# %% [markdown]
# Otra característica importante a revisar es la composición de las columnas. Contestar las preguntas: ¿Qué elementos tiene?, ¿Cuántos elementos distintos hay? son cosas que necesitamos saber.

# %%
# Revisando los elementos de una columna
base_nueva['Make']
# Out:
# 0       ACURA
# 4373    ACURA
# 4372    ACURA
# 4371    ACURA
# 5454    ACURA
#         ...
# 5442    VOLVO
# 5441    VOLVO
# 5440    VOLVO
# 5438    VOLVO
# 7384    VOLVO
# Name: Make, Length: 7385, dtype: object

# %% [markdown]
# Podemos oobtener todos los elementos de la columna "Make", sin embargo, no vemos cuántos distintos hay, por esto se usa la siguiente función

# %%
base_nueva['Make'].unique()
# Out:
# array(['ACURA', 'ALFA ROMEO', 'ASTON MARTIN', 'AUDI', 'BENTLEY', 'BMW',
#        'BUGATTI', 'BUICK', 'CADILLAC', 'CHEVROLET', 'CHRYSLER', 'DODGE',
#        'FIAT', 'FORD', 'GENESIS', 'GMC', 'HONDA', 'HYUNDAI', 'INFINITI',
#        'JAGUAR', 'JEEP', 'KIA', 'LAMBORGHINI', 'LAND ROVER', 'LEXUS',
#        'LINCOLN', 'MASERATI', 'MAZDA', 'MERCEDES-BENZ', 'MINI',
#        'MITSUBISHI', 'NISSAN', 'PORSCHE', 'RAM', 'ROLLS-ROYCE', 'SCION',
#        'SMART', 'SRT', 'SUBARU', 'TOYOTA', 'VOLKSWAGEN', 'VOLVO'],
#       dtype=object)

# %% [markdown]
# Con esto obtenemos todos los valores distintos que se encuentran en la columna "Make"

# %% [markdown]
# Resulta interesante hacerlo con las columnas "Model" y "Vehicle_Class"

# %%
base_nueva['Model'].unique()
# Out:
# array(['ILX', 'MDX SH-AWD ELITE', 'MDX SH-AWD', ..., 'S60 T6',
#        'XC70 T5 AWD', 'V90 CC T5 AWD'], dtype=object)

# %%
base_nueva['Vehicle_Class'].unique()
# Out:
# array(['COMPACT', 'SUV - SMALL', 'MID-SIZE', 'TWO-SEATER', 'MINICOMPACT',
#        'SUBCOMPACT', 'FULL-SIZE', 'STATION WAGON - SMALL',
#        'SUV - STANDARD', 'PICKUP TRUCK - SMALL',
#        'SPECIAL PURPOSE VEHICLE', 'PICKUP TRUCK - STANDARD',
#        'VAN - PASSENGER', 'VAN - CARGO', 'MINIVAN',
#        'STATION WAGON - MID-SIZE'], dtype=object)

# %% [markdown]
# ## Valores nulos

# %% [markdown]
# Continuando con el análisis de los datos, debemos observar a fondo los elementos que componen al dataframe. En vista de que tenemos un dataframe muy grande, resulta complicado visualizar toda la base en una sola exhibición, por lo que el estudio se realizará solo para encontrar valores nulos.

# %% [markdown]
# Para esto se utiliza la siguiente función que retorna 'True' en la columna si esta contiene algún elemento nulo, o bien, 'False' si no contiene ninguno

# %%
base_nueva.isnull().any()
# Out:
# Make                                False
# Model                               False
# Vehicle_Class                       False
# Engine_Size(L)                      False
# Cylinders                           False
# Transmission                        False
# Fuel_Type                           False
# Fuel_Consumption_City(L/100 km)     False
# Fuel_Consumption_Hwy(L/100 km)      False
# Fuel Consumption Comb (L/100 km)    False
# Fuel_Consumption_Comb(mpg)          False
# CO2_Emissions(g/km)                 False
# dtype: bool

# %% [markdown]
# Con este resultado podemos decir que nuestra base de datos no contiene valores nulos. Para estar seguros, podemos revisar otra función que retorna el número de elementos nulos que contiene cada columna

# %%
base_nueva.isnull().sum()
# Out:
# Make                                0
# Model                               0
# Vehicle_Class                       0
# Engine_Size(L)                      0
# Cylinders                           0
# Transmission                        0
# Fuel_Type                           0
# Fuel_Consumption_City(L/100 km)     0
# Fuel_Consumption_Hwy(L/100 km)      0
# Fuel Consumption Comb (L/100 km)    0
# Fuel_Consumption_Comb(mpg)          0
# CO2_Emissions(g/km)                 0
# dtype: int64

# %% [markdown]
# Dado que obtuvimos 0 en todas las columnas, podemos afirmar que nuestra base no contiene elementos nulos.

# %% [markdown]
# ## Eliminación de columnas

# %% [markdown]
# Antes de eliminar columnas del dataframe, debemos analizar los objetivos que se tienen en mente al trabajar con esta base para no eliminar datos que se pudieran requerir para contestarlos.

# %% [markdown]
# **Recordando...**
# Objetivo principal:
# + Predecir las emisiones de CO2 (g/km) de los automóviles
#
# Objetivos secundarios y preguntas de interés:
# + Establecer si el tipo de gasolina utilizada influye en las emisiones producidas
# + Determinar las armadoras que tienen menor índice de emisiones
# + ¿Qué clases de vehículo representan un mayor riesgo al ambiente?
# + ¿La transmisión del automóvil hace una diferencia al momento de emitir CO2?

# %% [markdown]
# Del mismo modo, nos apoyaremos en la gráfica de correlación entre las diferentes variables (en este caso las columnas) para conocer cómo se relacionan entre sí.
# Tomando en cuenta cómo clasificamos los valores del coeficiente de correlación:
#
# Relación inversa | Nivel de asociación | Relación positiva
# :--------: | :-------: | :-------:
# r = -1 | Perfecta | r = 1
# -1 < r < -0.9 | Muy fuerte | 0.9 < r < 1
# -0.9 < r < -0.7 | Fuerte | 0.7 < r < 0.9
# -0.7 < r < -0.4 | Moderado | 0.4 < r < 0.7
# -0.4 < r < -0.2 | Débil | 0.2 < r < 0.2
# -0.2 < r <= 0 | Despreciable | 0 < r <= 0.2

# %%
f,ax=plt.subplots(figsize = (7,7))
sns.heatmap(base_nueva.corr(),annot= True,linewidths=0.5,fmt = ".1f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Mapa de correlación')
plt.show()

# %% [markdown]
# En cuanto a conclusiones sobre el mapa de correlación, observamos que la mayoría de las variables mantienen una relación positiva (relación directa) teniendo  un nivel de asociación que va desde moderado hasta muy fuerte. Sin embargo, existe una columna que obtenemos un resultado contrario, el cual es la columna 'Fuel_Consumption_Comb(mpg)', esta relación es inversa en todos los casos. Puesto que estamos buscando variables que se relacionen con las emisiones de CO2 para poder predecirlas, vamos a considerar variables que sumen y aporten características para lograr esto. Por lo que en este caso, 'Fuel_Consumption_Comb(mpg)' tiene que ser dejada a un lado. Otra justificación que se puede mencionar es el hecho de que esta variable es la misma que 'Fuel Consumption Comb (L/100 km)', sólo cambian las unidades en la que son medidas; una está en litros por cada 100 km y la otra en millas por galón, por lo tanto eliminaremos esta columna ya que no será tomada en cuenta.

# %% [markdown]
# Base de datos antes de la eliminación de la columna Fuel_Consumption_Comb(mpg):

# %%
base_nueva.head(2)
# Out:
#        Make             Model  ... Fuel_Consumption_Comb(mpg)  CO2_Emissions(g/km)
# 0     ACURA               ILX  ...                         33                  196
# 4373  ACURA  MDX SH-AWD ELITE  ...                         26                  251
#
# [2 rows x 12 columns]

# %% [markdown]
# Proceso de eliminar la columna elegida:

# %%
base_nueva = base_nueva.drop(['Fuel_Consumption_Comb(mpg)'], axis=1)

# %% [markdown]
# Revisar que se haya realizado la eliminación:

# %%
base_nueva.head(2)
# Out:
#        Make  ... CO2_Emissions(g/km)
# 0     ACURA  ...                 196
# 4373  ACURA  ...                 251
#
# [2 rows x 11 columns]

# %%
base_nueva.columns
# Out:
# Index(['Make', 'Model', 'Vehicle_Class', 'Engine_Size(L)', 'Cylinders',
#        'Transmission', 'Fuel_Type', 'Fuel_Consumption_City(L/100 km)',
#        'Fuel_Consumption_Hwy(L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'CO2_Emissions(g/km)'],
#       dtype='object')

# %% [markdown]
# La columna ya no forma parte de nuestra base de datos.

# %% [markdown]
# #### Regresando a la revisión de las columnas y los objetivos...

# %% [markdown]
# Podemos notar de primera mano que, los consumos de gasolina, el tamaño del motor, los cilindros y las emisiones de CO2 se podrían utilizar para predecir las emisiones de CO2. Así como ocupamos a las armadoras, las clases de vehículo, el tipo de gasolina que se usa y la transmisión para algunas preguntas de interés y objetivos secundarios. Por lo que sólo resta el modelo de los automóviles que es el que, a primera impresión, no se ha utilizado.

# %% [markdown]
# Sin embargo, esto no quiere decir que no se vaya a emplear en el trabajo. Como sabemos, el vehículo es el responsable de emitir el CO2, por lo que va relacionado directamente con este. Así mismo, podría emplearse en alguna gráfica que indique los modelos de vehículos con mayor emisión de CO2, entre otras posibles alternativas.

# %% [markdown]
# Tomando todo esto en cuenta, se conluye que no se eliminará una columna adicional dado que en algún punto del trabajo podrían llegar a emplearse. Y, como sabemos, la información no se podría recuperar en caso de ser eliminada.

# %% [markdown]
# ## Guardar un nuevo archivo

# %% [markdown]
# Para finalizar, se puede crear un nuevo archivo con todos los cambios que se han realizado, para que, cuando se vuelva a necesitar la base, no se tengan que realizar todos los cambios nuevamente.

# %%
base_nueva.to_csv('Emision_CO2_automoviles.csv', index=False, sep = ',')
# se crea un archivo csv separado o delimitado por comas

# %% [markdown]
# ## Estadística básica de los datos

# %% [markdown]
# Basándonos en los objetivos principales y secundarios, podemos hacer uso de diferentes funciones matemáticas para obtener datos relevantes que nos ayudarán a cumplir las metas establecidas en un principio.

# %% [markdown]
# Dado que nuestro objetivo principal es predecir las emisiones de C02 de los automóviles; debemos comprender cómo actúan los datos de la columna 'CO2 Emissions(g/km)', conocer información tal como: la media que tiene, valor mínimo, valor máximo, etc., nos ayuda a tener una idea de qué datos obtendremos en el futuro.
#
# Para esto usaremos la función '.describe()' para obtener los datos estadísticos más importantes, como pueden ser la media, la desviación estandar, etc.; mientras que la función '.sum()' nos arroja el total de CO2 emitido.

# %%
base_nueva['CO2_Emissions(g/km)'].describe()
# Out:
# count    7385.000000
# mean      250.584699
# std        58.512679
# min        96.000000
# 25%       208.000000
# 50%       246.000000
# 75%       288.000000
# max       522.000000
# Name: CO2_Emissions(g/km), dtype: float64

# %%
base_nueva['CO2_Emissions(g/km)'].sum()
# Out:
# 1850568

# %% [markdown]
# Los datos anteriores nos hablan que en promedio se emite un total de 250.58 g/km de CO2, con un máximo obtenido de 522 g/km y un mínimo de 96 g/km, y con una desviación estandar de 58.51 g/km; observando que el 50% de los automóviles emite entre 208 y 288 g/km de CO2; emitiendo un total de CO2 de 1,850,568 g/km tomando en cuenta 7,385 automóviles.
# Nos beneficia mucho el conocer estos datos, ya que nos puede dar una idea de lo que podríamos obtener a la hora de hacer nuestras predicciones en las emisiones de CO2 de ciertos automóviles; y asímismo, considerar datos que no son de esperarse.

# %% [markdown]
# Otro punto importante a tener en cuenta, es cómo los diferentes automóviles (por armadora o clase) afectan al ambiente mediante la emisión de CO2, para esto nos podemos basar en el porcentaje en que dichos carros contribuyen con el gas, así como en la media que estos datos tienen y la cantidad de valores con los que se cuenta.
#
# Se necesitan estas tres métricas para poder tener una imágen clara del verdadero comportamiento, ya que una proporción grande de CO2 emitido nos podría indicar que este autómovil o armadora tiene un índice alto en contribución, sin embargo, puede tener el mismo promedio de CO2 emitido que otra con algún porcentaje menor dado, a lo que también se debe de tomar en cuenta el número de elementos que se consideran.
#
# Finalmente, al analizar estas tres métricas como un conjunto, lograremos interpretar mejor los resultados obtenidos en cada sección.

# %% [markdown]
# ### Porcentaje, promedio y cantidad de emisión de CO2...

# %% [markdown]
# ***Por armadora***
# ***(menor a mayor)***

# %%
cols= ['Make']
base_2= base_nueva.groupby(cols)
Total=base_nueva['CO2_Emissions(g/km)'].sum()
base_nueva_2=base_2[['CO2_Emissions(g/km)']].sum()/Total*100
base_nueva_2.sort_values('CO2_Emissions(g/km)',ascending=True)
# Out:
#                CO2_Emissions(g/km)
# Make
# SRT                       0.042041
# SMART                     0.057280
# BUGATTI                   0.084623
# SCION                     0.238305
# ALFA ROMEO                0.364591
# GENESIS                   0.384801
# FIAT                      0.758362
# ASTON MARTIN              0.862546
# ACURA                     0.870165
# LAMBORGHINI               0.887944
# BENTLEY                   0.902155
# MITSUBISHI                1.029306
# MASERATI                  1.048705
# ROLLS-ROYCE               1.049624
# CHRYSLER                  1.170614
# BUICK                     1.297169
# LAND ROVER                1.321216
# LINCOLN                   1.386655
# INFINITI                  1.482734
# RAM                       1.532665
# VOLVO                     1.541527
# SUBARU                    1.646305
# MAZDA                     1.883800
# MINI                      2.167118
# HONDA                     2.199703
# ...

# %% [markdown]
# Como podemos observar, algunos marcas reconocidas a nivel mundias como lo son 'Alfa romeo' y 'Bugatti' impactan de una manera muy pequeña en la emisiones del CO2; en caso contrario, armadoras como 'Chevrolet' o 'Ford', compañias igual de reconocidas, influyen de manera impactante. Por lo que, entre más grande sea el porcentaje, nos quiere dar a entender que cierto modelo/marca afecta de manera grave en las emisiones de CO2, y del mismo modo, nos da a conocer que automóviles tienen un impacto menor.

# %%
cols= ['Make']
base_2= base_nueva.groupby(cols)
base_nueva_2=base_2[['CO2_Emissions(g/km)']].mean()
base_nueva_2.sort_values('CO2_Emissions(g/km)',ascending=True)
# Out:
#                CO2_Emissions(g/km)
# Make
# SMART                   151.428571
# HONDA                   190.219626
# FIAT                    192.246575
# MAZDA                   193.672222
# MINI                    196.588235
# SCION                   200.454545
# MITSUBISHI              200.505263
# HYUNDAI                 208.871429
# VOLKSWAGEN              209.335025
# KIA                     214.294372
# SUBARU                  217.614286
# ACURA                   223.652778
# TOYOTA                  224.424242
# ALFA ROMEO              224.900000
# VOLVO                   230.056452
# BUICK                   233.058252
# NISSAN                  236.864865
# LEXUS                   241.112360
# CHRYSLER                246.170455
# JEEP                    250.342629
# AUDI                    250.846154
# BMW                     254.007590
# INFINITI                254.064815
# PORSCHE                 258.941489
# FORD                    260.988854
# ...

# %% [markdown]
# Sin embargo, a la hora de conocer el promedio por armadoras, nos contradice el punto anterior, dado que 'Bugatti' tiene una media de 522 g/km en emisiones, caso contrario de 'Alfa romeo' que si apoya la idea anterior, con un promedio de 224.90. Sin embargo, no está muy alejado de 'Ford' y 'Chevrolet' con un promedio que tiende a 260 g/km aproximadamente.
# Para poder entender el por qué de estas contradicciones, debemos conocer la cantidad de automoviles por armadora, como lo mostramos a continuación:

# %%
cols= ['Make']
base_2= base_nueva.groupby(cols)
base_2[['Model']].count().sort_values('Model',ascending=True).rename(columns = {'Model':'Cantidad'})
# Out:
#                Cantidad
# Make
# SRT                   2
# BUGATTI               3
# SMART                 7
# SCION                22
# GENESIS              25
# ALFA ROMEO           30
# LAMBORGHINI          41
# BENTLEY              46
# ASTON MARTIN         47
# ROLLS-ROYCE          50
# MASERATI             61
# ACURA                72
# FIAT                 73
# LAND ROVER           85
# CHRYSLER             88
# MITSUBISHI           95
# LINCOLN              96
# RAM                  97
# BUICK               103
# INFINITI            108
# VOLVO               124
# SUBARU              140
# CADILLAC            158
# JAGUAR              160
# LEXUS               178
# MAZDA               180
# VOLKSWAGEN          197
# MINI                204
# HYUNDAI             210
# HONDA               214
# KIA                 231
# DODGE               246
# JEEP                251
# NISSAN              259
# AUDI                286
# GMC                 328
# TOYOTA              330
# ...

# %% [markdown]
# Una vez que conocemos la cantidad de vehículos por armadora, podemos entender por qué Chevrolet y Ford lideran las emisiones cuando se mide en porcentaje, es debido a que estas dos tienen una mayor cantidad de vehículos que el resto aunque no necesariamente su promedio de emisión es el más alto. También, destacamos como las armadoras menos contaminantes a 'Srt', 'Smart' y 'Bugatti', dado que si observamos los valores obtenidos en porcentajes, notaremos que son los menores gracias a que no se cuenta con muchos registros de estos, con 2, 7 y 3 respectivamente. Causa conflicto que el promedio de emisiones de Bugatti sea uno de los más altos junto con Srt debido a que en porcentaje no representa mucha parte del total, pero es debido a la cantidad de automóviles con los que cuenta.
#
# Como conclusión, la única armadora que se mantuvo coherente a lo largo de las métricas fue la de Smart, dado que tiene un bajo porcentaje de emisiones totales así como también un promedio bajo de emisión por automóvil. 7 automóviles tal vez no sean suficientes para decir con total seguridad que es una armadora responsable ambientalmente, pero fue la que destacó en este estudio.

# %% [markdown]
# ***Por clase de vehículo (mayor a menor)***

# %% [markdown]
# Del mismo modo, y llevando a cabo las mismas métricas a calcular, podemos hacer las divisiones por clase de vehículo, para asi poder intuir cuales representan un mayor riesgo al ambiente.

# %%
cols= ['Vehicle_Class']
base_2= base_nueva.groupby(cols)
Total=base_nueva['CO2_Emissions(g/km)'].sum()
base_nueva_2=base_2[['CO2_Emissions(g/km)']].sum()/Total*100
base_nueva_2.sort_values('CO2_Emissions(g/km)',ascending=False)
# Out:
#                           CO2_Emissions(g/km)
# Vehicle_Class
# SUV - SMALL                         15.539445
# MID-SIZE                            13.619710
# SUV - STANDARD                      12.107364
# COMPACT                             11.966380
# FULL-SIZE                            9.092290
# PICKUP TRUCK - STANDARD              8.765633
# SUBCOMPACT                           8.070387
# TWO-SEATER                           6.896747
# MINICOMPACT                          4.168126
# STATION WAGON - SMALL                2.724407
# PICKUP TRUCK - SMALL                 2.396886
# VAN - PASSENGER                      1.416646
# MINIVAN                              1.133976
# SPECIAL PURPOSE VEHICLE              0.988615
# STATION WAGON - MID-SIZE             0.683628
# VAN - CARGO                          0.429760

# %% [markdown]
# Podemos observar, dados los porcentajes, que las clases 'SUV-SMALL', 'MID-SIZE', 'SUV-STANDARD' y 'COMPACT' son las únicas que tienen más de un 10% cada una, también entre estas 4 clases conforman poco más del 50% del total de gases emitidos, lo que nos indica que estas clases podrían ser denominadas como las principales afectadoras al planeta.

# %%
cols= ['Vehicle_Class']
base_2= base_nueva.groupby(cols)
base_nueva_2=base_2[['CO2_Emissions(g/km)']].mean()
base_nueva_2.sort_values('CO2_Emissions(g/km)',ascending=False)
# Out:
#                           CO2_Emissions(g/km)
# Vehicle_Class
# VAN - PASSENGER                    397.212121
# VAN - CARGO                        361.500000
# SUV - STANDARD                     304.836735
# PICKUP TRUCK - STANDARD            301.513011
# PICKUP TRUCK - SMALL               278.968553
# TWO-SEATER                         277.454348
# FULL-SIZE                          263.316119
# MINIVAN                            262.312500
# SUBCOMPACT                         246.448845
# STATION WAGON - MID-SIZE           238.698113
# SPECIAL PURPOSE VEHICLE            237.597403
# MINICOMPACT                        236.607362
# SUV - SMALL                        236.292523
# MID-SIZE                           222.455428
# COMPACT                            216.679061
# STATION WAGON - SMALL              200.067460

# %% [markdown]
# Obteniendo un resultado casi similar como fue el caso cuando dividimos por armadora, muchos promedios tienden a mostrar contradicciones referente al porcentaje. Anteriormente obtuvimos que 'SUV-SMALL', 'MID-SIZE' y 'COMPACT' eran 3 de las 4 con mayor porcentaje; sin embargo, cuando calculamos el promedio, notamos que se encuentran entre los niveles de emisiones más bajos, mientras que 'SUV-STANDARD' permanece en niveles altos al igual que en su porcentaje. Esto se debe a que en esta parte se considera como promedio, por lo que en promedio no contaminan tanto pero al considerarse como un total sí lo hacen.
# A continuación obtendremos la cantidad respectiva por clase.

# %%
cols= ['Vehicle_Class']
base_2= base_nueva.groupby(cols)
base_2[['Make']].count().sort_values('Make',ascending=False).rename(columns = {'Make':'Cantidad'})
# Out:
#                           Cantidad
# Vehicle_Class
# SUV - SMALL                   1217
# MID-SIZE                      1133
# COMPACT                       1022
# SUV - STANDARD                 735
# FULL-SIZE                      639
# SUBCOMPACT                     606
# PICKUP TRUCK - STANDARD        538
# TWO-SEATER                     460
# MINICOMPACT                    326
# STATION WAGON - SMALL          252
# PICKUP TRUCK - SMALL           159
# MINIVAN                         80
# SPECIAL PURPOSE VEHICLE         77
# VAN - PASSENGER                 66
# STATION WAGON - MID-SIZE        53
# VAN - CARGO                     22

# %% [markdown]
# Al analizar toda esta información, entendemos finalmente que el porcentaje alto de emisiones por parte de 'SUV-SMALL', 'MID-SIZE' y 'COMPACT' se debe a que son los que mayor número de vehículos tienen y por ende se ve afectado en el porcentaje del total. Del mismo modo, 'SUV-STANDARD' es el cuarto con mayor número, lo que lo coloca de igual forma en una alta posición en emisiones totales, esto aunado a su promedio de emisión alto.

# %% [markdown]
# Para concluir, si nos fijamos en los porcentajes en que son responsables cada clase de vehículo, se tendría que señalar a los primeros 4 en la lista puesto que son los que tienen más de 10% del total cada uno. Sin embargo, no puede dejarse de lado el promedio de emisión puesto que también es importante. Si consideramos esto, 'SUV-SMALL', 'MID-SIZE' y 'COMPACT' tienen una posición alta sólo porque tienen una gran cantidad de vehículos pero con promedio pequeño, lo que hace que vaya sumando de a poco pero logre representar mucho en el total.

# %% [markdown]
# Otro factor importante al momento de analizar las emisiones de CO2 es el tipo de gasolina. Conociendo que existe una variación en la composición química de cada combustible, esto nos quiere decir que ciertos combustibles tiene una presencia mayor de átomos de carbono que otros, por lo que ante mayor uso, mayor emisión de gases de CO2.
# Ante esto, es importante comprender cómo se comporta cada combustible y su afectación al ambiente.

# %% [markdown]
# ***Por tipo de combustible***

# %%
cols= ['Fuel_Type']
base_2= base_nueva.groupby(cols)
Total=base_nueva['CO2_Emissions(g/km)'].sum()
base_nueva_2=base_2[['CO2_Emissions(g/km)']].sum()/Total*100
base_nueva_2.sort_values('CO2_Emissions(g/km)',ascending=False)
# Out:
#            CO2_Emissions(g/km)
# Fuel_Type
# X                    46.209002
# Z                    46.032948
# E                     5.500149
# D                     2.246391
# N                     0.011510

# %% [markdown]
# A primera vista podemos afirmar que tanto el tipo de gasolina "X" como el "Z" son los responsables de la actual problematica del efectivo invernadero. Sin embargo, debemos tener en cuenta el promedio correspondiente.

# %%
cols= ['Fuel_Type']
base_2= base_nueva.groupby(cols)
base_nueva_2=base_2[['CO2_Emissions(g/km)']].mean()
base_nueva_2.sort_values('CO2_Emissions(g/km)',ascending=False)
# Out:
#            CO2_Emissions(g/km)
# Fuel_Type
# E                   275.091892
# Z                   266.043410
# D                   237.548571
# X                   235.119329
# N                   213.000000

# %% [markdown]
# Al obtener el promedio de gases de CO2 emitidos por cada tipo de gasolina, observamos que existen 3 posibles grupos. El tipo E (etanol) y  Z (gasolina premium) tienen los dos promedios más altos y entre ellos parecen cercanos. El D (diesel) y X (gasolina regular) tienen un promedio bastante parecido en 236 unidades. Finalmente, el N (gas natural) tiene un promedio bajo de 213 unidades. A esta altura del estudio, podríamos decir que no existe una diferencia significativa dentro de los grupos que se formaron, sin embargo, pareciera existir una diferencia a la hora de comparar los elementos de un grupo con los de uno diferente, puesto que la media cambia considerablemente. Una vez que se establece esto, podemos preguntarnos: ¿Por qué obtuvimos porcentajes parecidos de gasolina premium y regular si aquí son diferentes?

# %%
cols= ['Fuel_Type']
base_2= base_nueva.groupby(cols)
base_2[['Make']].count().sort_values('Make',ascending=False).rename(columns = {'Make':'Cantidad'})
# Out:
#            Cantidad
# Fuel_Type
# X              3637
# Z              3202
# E               370
# D               175
# N                 1

# %% [markdown]
# Esto contesta nuestra duda, la base de datos contiene en su mayoría automóviles que utlizan el tipo de gasolina "X" y "Z", por lo que siempre es importante conocer todas las estadísticas descriptivas al tomar una decisión. Vemos claramente que se necesitaron de 400 automóviles más que utilizaran gasolina regular, para alcanzar el mismo porcentaje que los que utilizaron gasolina premium.
#
# Es un caso similar al que obtuvimos cuando agrupamos por armadoras, la cantidad de elementos en cada agrupación es muy distinta y sólo sobresalen dos tipos. Aún así, basándonos en el promedio que se obtiene por cada uno, podríamos pensar que la gasolina  influye al momento de medir las emisiones de CO2.

# %% [markdown]
# Por último, verificaremos si existe alguna diferencia entre las diferentes transmisiones al momento de emitir el CO2, por lo que dependiendo de cada transmisión existe un promedio de emisión, y así nos podemos dar una idea el cómo afecta.

# %% [markdown]
# ***Por tipo de transmisión***

# %%
cols= ['Transmission']
base_2= base_nueva.groupby(cols)
Total=base_nueva['CO2_Emissions(g/km)'].sum()
base_nueva_2=base_2[['CO2_Emissions(g/km)']].sum()/Total*100
base_nueva_2.sort_values('CO2_Emissions(g/km)',ascending=False)
# Out:
#               CO2_Emissions(g/km)
# Transmission
# Automatic               85.378003
# Manual                  14.621997

# %% [markdown]
# Como se observa, hay una gran diferencia en el porcentaje que de contaminacion de cada una de los dos tipos de transmision, y esto puede ser debido a que hay una gran cantidad de autos que son de transmision automatica, por lo que nuestro cálculo de porcentaje es sesgado hacia un lado.

# %%
cols= ['Transmission']
base_2= base_nueva.groupby(cols)
base_nueva_2=base_2[['CO2_Emissions(g/km)']].mean()
base_nueva_2.sort_values('CO2_Emissions(g/km)',ascending=False)
# Out:
#               CO2_Emissions(g/km)
# Transmission
# Automatic              254.835161
# Manual                 228.345992

# %% [markdown]
# Ahora, calculando la media nos damos cuenta que ambas oscilan un número cercano la media general que se habia calculado en un principio (media = 250), lo que nos preguntamos de nuevo, ¿Por qué hubo una gran diferencia en los porcentajes?

# %%
cols= ['Transmission']
base_2= base_nueva.groupby(cols)
base_2[['Make']].count().sort_values('Make',ascending=False).rename(columns = {'Make':'Cantidad'})
# Out:
#               Cantidad
# Transmission
# Automatic         6200
# Manual            1185

# %% [markdown]
# Basta con calcular la cantidad de autos con transmision automatica/manual para contestar la pregunta que se realizó anteriormente. Con los datos presentados, se tiene que hay una diferencia enorme en la cantidad de autos automáticos y manuales, por lo que se puede decir que los porcentajes se vieron afectados por este factor.
#
# Dado los datos obtenidos, podemos afirmar que sí existe una diferencia según la transmisión del automóvil, ya que los que tienen una transmisión automática emiten más C02 que los que tienen una transmisión manual. Sin embargo, no quiere decir que sólo esta variable esté relacionada directamente con la emisión de CO2, porque como lo vimos anteriormente con el mapa de correlación, existen más relaciones directas con las otras variables, incluso mejores.

# %% [markdown]
# En este punto, se podrían tomar en cuenta los valores obtenidos en la parte estadística, tales como: promedios, proporciones o totales, para intentar contestar las preguntas de interés y los objetivos planteados. Sin embargo, es necesario realizar un análisis más profundo de esto, por lo que se seguirán estudiando los comportamientos de las variables en la siguiente sección por medio de análisis gráfico para poder, en un momento dado, realizar conclusiones al respecto uniendo ambas secciones.

# %% [markdown]
# ## Análisis gráfico de variables

# %% [markdown]
# Para la parte de análisis gráfico se comenzará por mostrar la relación que guardan las variables entre sí. Esto resulta muy útil debido a que se puede apreciar a simple vista si existe una relación entre ellas de manera directa, inversa o no existe tal relación; la gráfica nos ayuda a visualizar los números que se mostraron anteriormente (véase la parte de *eliminación de columnas*). Es importante mencionar que la gráfica sólo considera las variables que contienen datos numéricos, debido a que la correlación se necesita medir con datos de este tipo.

# %%
sns.pairplot(base_nueva[['CO2_Emissions(g/km)', 'Engine_Size(L)', 'Cylinders', 'Fuel Consumption Comb (L/100 km)',
                        'Fuel_Consumption_City(L/100 km)','Fuel_Consumption_Hwy(L/100 km)']])

# %% [markdown]
# En la diagonal principal de la matriz de correlación se encuentran las gráficas pertinentes a las distribuciones de cada una de las variables. Podemos notar que, en cada una de las gráficas de dispersión, se observa una relación entre variables, lo cual nos indica que estas sí se correlacionan. La relación se determina en base a la forma de la gráfica. En todos los casos, tenemos gráficas con forma ascendente, lo cual nos dice que la relación es directa.
#
# Lo más valioso a destacar de estas gráficas es que podemos afirmar el hecho de que las variables de la base se relacionan con las emisiones de CO2, esto es importante dado que está establecido en nuestro objetivo principal el poder predecir las emisiones, así que podremos hacer uso de estas variables para explicar la variable de respuesta.

# %% [markdown]
# Una vez que hemos establecido la existencia de relación entre variables, es de sumo interés analizar por separado el comportamiento de la variable más importante, las emisiones de CO2 (CO2_Emissions(g/km)), con el fin de identificar cómo está compuesta esta variable, es decir, poder observar entre qué valores oscilan las emisiones, así como indicar una posible distribución que se asemeje a esta.

# %%
base_nueva['CO2_Emissions(g/km)'].plot.hist()

# %% [markdown]
# A simple vista se puede destacar que el valor mínimo de las emisiones se encuentra cercano al 100, así como que el valor máximo encontrado supera los 500; esto se respalda con la información estadística encontrada previamente. A partir de esta gráfica, se nota que la mayor concentración de datos ocurre entre los valores cercanos al 200 por izquierda y 300, lo que indica que gran parte de las emisiones son con estos valores. De la misma manera, si se observa detenidamente el histograma, se puede apreciar una similitud con la distribución normal, por lo que podríamos llegar a pensar que las emisiones de CO2 siguen una distribución normal con media ubicada entre 220(g/km) y 270(g/km). Si nos fijamos en los estadísticos encontrados en la sección anterior, podemos recordar que la media de las emisiones era 250(g/km), por lo que con esta gráfica también nos hace más sentido.
# Una vez que hemos estudiado las características y comprendemos mejor a esta variable podemos esperar que se puedan predecir los valores de las emisiones de CO2 con el uso de los demás componentes de la base de datos. Esto último se intentará probar en secciones futuras del estudio.

# %% [markdown]
# Como se ha establecido a lo largo del trabajo, el objetivo principal es explicar las emisiones con el uso de las variables que se tienen, estas variables necesitan ser numéricas para poder involucrarlas en una regresión lineal. Sin embargo, también se tienen variables con distintas categorías que, por razones obvias, no son numéricas. Esto último no es un impedimento para poder establecer algún tipo de relación entre estas variables y la variable de respuesta (emisiones). A continuación se estudiará el caso de la variable 'Fuel_Type', la cual indica el combustible que utiliza el automóvil.

# %%
base_nueva['Fuel_Type'].unique()
# Out:
# array(['Z', 'D', 'X', 'E', 'N'], dtype=object)

# %% [markdown]
# Podemos recordar que:
# + X = Gasolina Regular
# + Z = Gasolina Premium
# + D = Diesel
# + E = Etanol (E85)
# + N =Gas natural

# %% [markdown]
# Si se utiliza un gráfico de caja y bigotes, se podrá notar la diferencia (si es que existe) entre cada tipo de combustible utilizado. Se busca determinar si es que el combustible afecta de una manera u otra a las emisiones de CO2.

# %%
df = base_nueva[base_nueva.Fuel_Type.isin(base_nueva.Fuel_Type.value_counts().head(5).index)]
px.box(
    df,
    x='Fuel_Type',
    y='CO2_Emissions(g/km)',
    color='Fuel_Type'
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ee712456-f3f8-4115-a818-7dbae2333799" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ee712456-f3f8-4115-a818-7dbae2333799")) {
#                     Plotly.newPlot(
#                         'ee712456-f3f8-4115-a818-7dbae2333799',
# ...

# %% [markdown]
# Lo primero que podemos notar es que del tipo N (gas natural) no hay muchos elementos que puedan ser considerados, mientras que de los otros 4 elementos sí hay suficientes datos. Podemos notar que el tipo X y Z (gasolina regular y gasolina premium, respectivamente) tienen picos más altos que los otros dos, lo que daría la impresión de que son, tal vez, mayores contaminantes. También podemos ver que en ambos tipos los valores se ubican entre los 100 y 500, con una frecuencia considerable dados los datos previos. Si analizamos su media, nos daremos cuenta de que la media de la gasolina premium es mayor a la gasolina regular, esto queda explicado por la gran cantidad de datos atípicos que tiene la gasolina premium. Si quitaramos los datos atípicos de ambas gráficas, podríamos considerar que fueran un tanto iguales dada la ligera similitud entre ellas, debido a que no es el caso, tenemos que decir que sí existe una diferencia entre usar gasolina premimum y gasolina regular, puesto que la premium provoca un mayor grado de contaminación.
#
# Estudiaremos los combustibles D y E (diesel y etanol, respectivamente). Del tipo D podemos ver que los elementos más pequeños son mayores a los menores del tipo Z y X; de nueva cuenta, podríamos considerar que existe una diferencia por encontrarse unos niveles más altos. Sin embargo, al estudiar únicamente la caja D (diesel) podremos ver que está al mismo nivel que la X, esto queda explicado cuando se calculó su media, ahí determinamos que se tenía, en promedio, los mismos niveles de contaminación, por lo que no existe una diferencia significativa entre la gasolina regular y el diesel. Por otro lado, al observar la caja E (etanol), nos damos cuenta que está en unos niveles por encima del resto, esto se descubrió cuando establecimos que tenía la mayor media en comparación a las demás, por lo que decimos que existe una diferencia entre usar etanol y gasolina regular/diesel. Sin embargo, al compararla con la gasolina premium, podemos ver que se encuentra en niveles parecidos, por lo que no existe tanta diferencia.
#
# Como conclusión final a este gráfico, decimos que evidentemente existe una diferencia entre usar un combustible u otro. Sin embargo, esta diferencia no es tan grande como se esperaría que fuera. Si juntamos el análisis de esta gráfica con el hecho en la parte estadística, podemos concluir que existe diferencia entre la gasolina regular y premium, así como también existe entre usar etanol o gas natural. Todo esto en base a la información que se tiene.

# %% [markdown]
# Dados los resultados de la relación del combustible utilizado y las emisiones de CO2, resulta interesante fijarnos ahora en el tipo de transmisión que tiene el automóvil. Es creído por algunas personas que esto tiene algo que ver respecto a la contaminación que emanan, puesto que cada automóvil es diseñado de una forma distinta y sigue distintos mecanismos, por lo que se puede llegar a pensar que existe una diferencia entre estos dos.
#
# Así como en el ejemplo anterior, la variable 'Transmission' es categórica; esta vez emplearemos la metodología utilizada previamente. Al utilizar este estilo de gráfica, podemos visualizar de una mejor manera las diferencias que se presenten entre una y otra, ya que viene señalada la mediana, mínimo, máximo y cuartiles dentro de ella, lo que nos permite un mejor entendimiento de su composición. Como sólo hay 2 tipos: automático y manual, es más fácil compararlas.

# %%
df = base_nueva[base_nueva.Transmission.isin(base_nueva.Transmission.value_counts().head(5).index)]
px.box(
    df,
    x='Transmission',
    y='CO2_Emissions(g/km)',
    color='Transmission'
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ff6f85a0-228d-4f30-aa1f-0c0b7d72c6bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ff6f85a0-228d-4f30-aa1f-0c0b7d72c6bf")) {
#                     Plotly.newPlot(
#                         'ff6f85a0-228d-4f30-aa1f-0c0b7d72c6bf',
# ...

# %% [markdown]
# Viendo esta gráfica, podemos decir que la transmisión que se utiliza en los automóviles sí afecta a la cantidad de gas que emana, puesto que la distribución de ambas categorías es distinta y no se observan similitudes entre ellas. Hay que destacar que, en promedio, los gases emitidos por unidades con transmisión automática son mayores que los que utilizan una manual, esta inferencia se logra gracias a que la caja azul (automáticos) se localiza más arriba que la caja naranja (manuales). Otro punto a notar, es que el rango de valores que se tiene en los automáticos es más amplio que en la naranja, lo que nos indica una varianza mayor en los datos, que probablemente haga que se encuentren valores por encima del promedio con bastante normalidad.
#
# Por lo tanto, se puede decir que el tipo de transmisión utilizada en el vehículo, influye en la emisión de CO2 que se hace ya que los automáticos afectan más al ambiente que los manuales; esto en base a los resultados obtenidos en el análisis estadístico y gráfico.

# %% [markdown]
# Hasta este punto se ha estudiado el comportamiento de las emisiones de CO2 cuando se les analiza en conjunto con el combustible que utiliza y con la transmisión que se tiene; sin embargo, hace falta el objeto principal, el automóvil. Los automóviles son los acusados principales cuando se emiten los gases. Las personas no acusan directamente a la transmisión, el combustible u otro componente del vehículo, sino, más bien, lo hacen con el vehículo. Por esto, se estudiará el comportamiento de las emisiones de CO2 por clase de vehículo. Es sabido que existen diversas clases de vehículos tales como: compactos, pequeños, medianos, camionetas pickup, entre otros; por lo que es de interés mostrar si las emisiones que hacen estos automóviles se relacionan con la clase de vehículo que son.

# %% [markdown]
# Para un mejor entendimiento de este problema, se analizará la variable 'Vehicle_Class' de manera detallada, puesto que es uno de los puntos importantes de este trabajo. Se comenzará con información básica para terminar con una conclusión de lo establecido previamente.

# %%
base_nueva['Vehicle_Class'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Con la gráfica de barras mostrada anteriormente podemos ver que en la base de datos abundan vehículos de la clase 'SUV-SMALL', 'MID-SIZE' y 'COMPACT' puesto que en los tres casos se tienen más de mil registros. Por otra parte, se tienen pocos registros de 'VAN-CARGO', si en un futuro afecta al estudio, no se tomará en cuenta para las conclusiones, así como tampoco se considerarán categorías que no resulten significativas en cierto momento.

# %% [markdown]
# Una vez que tenemos una idea de la cantidad de vehículos que se tiene por clase, podemos formar una cuestión más importante que es ¿cuánto aporta cada clase de vehículo a las emisiones de CO2?, por medio de una gráfica de pastel se podrán observar mejor estos porcentajes

# %%
cols= ['Vehicle_Class']
base_2= base_nueva.groupby(cols)
base_nueva_2=base_2[['CO2_Emissions(g/km)']].sum()
base_nueva_2
# Out:
#                           CO2_Emissions(g/km)
# Vehicle_Class
# COMPACT                                221446
# FULL-SIZE                              168259
# MID-SIZE                               252042
# MINICOMPACT                             77134
# MINIVAN                                 20985
# PICKUP TRUCK - SMALL                    44356
# PICKUP TRUCK - STANDARD                162214
# SPECIAL PURPOSE VEHICLE                 18295
# STATION WAGON - MID-SIZE                12651
# STATION WAGON - SMALL                   50417
# SUBCOMPACT                             149348
# SUV - SMALL                            287568
# SUV - STANDARD                         224055
# TWO-SEATER                             127629
# VAN - CARGO                              7953
# VAN - PASSENGER                         26216

# %%
clases = ['COMPACT', 'FULL-SIZE', 'MID-SIZE', 'MINICOMPACT', 'PICKUP TRUCK-SMALL', 'PICKUP TRUCK-STANDARD',
         'STATION WAGON-SMALL', 'SUBCOMPACT', 'SUV-SMALL', 'SUV-STANDARD',
         'TWO-SEATER', 'VAN-PASSENGER',  'SPECIAL PURPOSE VEHICLE', 'MINIVAN']
suma = [221446, 168259, 252042, 77134, 44356, 162214, 50417, 149348, 287568, 224055, 127629, 26216,  18295, 20985]

# %%
plt.pie(suma, labels=clases)
plt.axis("equal")
plt.show()

# %% [markdown]
# A partir de esta gráfica podemos conocer la distribución que se tiene cuando se habla del total de los gases de CO2 emitidos por clase de automóvil. Resaltando las aportaciones de 'SUV-SMALL', 'SUV-STANDARD', 'MID-SIZE' y 'COMPACT' que son los mismos que habíamos mencionado previamente en la sección de total de vehículos por clase.

# %% [markdown]
# A continuación se realizará un gráfico de violín, con el objetivo de comparar y apreciar las diferencias que existen entre cada clase de vehículos. Sólo se hará para las clases con mayor cantidad de elementos y porcentaje de emisión, puesto que son nuestro objeto de estudio. Se dejarán de lado las categorías que no nos indican información suficiente para realizar conclusiones.

# %%
df = base_nueva[base_nueva.Vehicle_Class.isin(base_nueva.Vehicle_Class.value_counts().head(5).index)]

sns.violinplot(
    x='Vehicle_Class',
    y='CO2_Emissions(g/km)',
    data=df
)
# Out:
# <AxesSubplot:xlabel='Vehicle_Class', ylabel='CO2_Emissions(g/km)'>

# %% [markdown]
# En la gráfica se muestran las 5 clases más representativas de automóviles que se tienen. Podemos empezar comentando que 'FULL-SIZE' y 'SUV-STANDARD' destacan de las otras 3 puesto que sus valores se encuentran por encima del resto, esto nos habla de que ambas medias son más grandes cuando se compara con las demás. Esto último se puede confirmar en la sección de estadística donde calculamos las medias para cada clase. Además de esto, es importante mencionar que 'COMPACT', 'SUV-SMALL' y 'MID-SIZE' muentran una distribución de valores parecida ya que el rango de estos y la concentración de los mismos se ubica en una zona similar. Si comentamos acerca de la media de las clases, podemos dar a destacar que la media de los primeros tres violines es similar, dada su ubicación. Cuando hablamos acerca de la densidad de los datos, notamos que parecen distribuciones normales. Como se había comentado previamente, la distribución de las emisiones de CO2 parecía de una distribución normal. Al graficar estas clases, su densidad queda parecida a una normal, a excepción, tal vez, la clase 'MID-SIZE', puesto que no se percibe claramente la forma de una campana.

# %% [markdown]
# ## Conclusión global

# %% [markdown]
# De la mano de la estadística descriptiva y el análisis gráfico pudimos entender mejor la base de datos que estamos trabajando. Cuando se trabaja con dataframes que son muy extensos resulta tedioso estudiar todas las componentes de una en una para lograr entenderlo, así como también visualizar la información que se tiene ya que en muchas de las ocasiones esto ni siquiera es posible, por lo que el análisis gráfico nos ayuda a comprender mejor los datos que estamos procesando. Las estadísticas básicas, por otro lado, nos arrojan resultados de una manera rápida para conocer y darnos una idea sencilla del comportamiento de los datos, dependiendo de cómo se use, resulta una herramienta muy útil.
#
# Conforme se fue avanzando en el trabajo, nos dimos cuenta de que algunos datos no eran sencillos de trabajar, por lo que se decidió editarlos para lograr un mejor proceso. Algunos de estos ejemplos fueron: cambiar los nombres de las columnas, cambiar los valores de las columnas, eliminar una columna, entre otros. Hacer estos cambios beneficia mucho al trabajo puesto que logramos tener resultados que son más fáciles de interpretar y de calcular.
#
# Gracias a la estadística básica que se realizó en conjunto con el análisis gráfico, pudimos resolver algunos de los objetivos que se habían planteado en un inicio así como ciertas preguntas de interés:
#
# **Conclusiones previas de los objetivos planteados**
# *Tipo de combustible:*
# Observamos que existe una diferencia a la hora de emitir gases de CO2 dependiendo del tipo de combustible que haya sido empleado. Se categorizó en tres grupos el tipo de combustible. El primer grupo es formado por la gasolina regular y el diesel, ambos comparten una media bastante parecida. El segundo grupo es el de la gasolina premium y el etanol, estos dos tipos provocan mayores efectos al ambiente al producir, en promedio, una mayor emisión. Por último quedó el gas natural que al no tener suficientes datos no se pudo clasificar de una manera adecuada y quedó en solitario con la media más baja. Como este último no tuvo más datos, no podemos decir que siempre se comporte así. Por lo tanto establecimos que existe una diferencia con el uso de combustible.
#
# *Armadoras:*
# Al trabajar con las armadoras se tuvieron problemas debido a que existe gran variedad en la base de datos. Sin embargo, se rescataron resultados que hay que mencionar. La armadora "Smart" tiene el reconocimiento como la de menor índice ya que guarda una proporción adecuada entre el porcentaje que aporta al total de emisiones hechas y el promedio de emisiones por automóvil, se mantuvo en niveles bajos en ambas pruebas. Uno de los principales problemas en esta sección fue que las proporciones indicaban mayores aportaciones de ciertas armadoras que, al estudiarlas, nos dábamos cuenta que fue gracias a la cantidad de vehículos que poseían, por lo que no resulta convincente del todo, si se tuvieran en estudio la misma cantidad de automóviles por armadora, resultaría interesante medir esta aportación, por tanto, actualmente sólo podemos medirlo en base a los promedios obtenidos de emisión.
#
# *Clases de vehículos:*
# Los vehículos que representan una mayor amenaza al ambiente son los FULL-SIZE y SUV-STANDARD debido a que tienen un promedio alto de emisión por unidad así como también se tiene una gran cantidad de estos autos en circulación, por lo que constantemente están afectando al planeta. En segundo lugar, se encuentran los de las clases COMPACT, MID-SIZE y SUV-SMALL porque son los que tienen mayor cantidad de elementos y representan una proporción alta del gas contaminante; aunque su promedio de emisión no sea tan alto, es de considerar que actualmente son los responsables de la situación mundial.
#
# *Transmisión:*
# Encontramos que los gases emitidos por un automóvil también se relacionan con la transmisión que este tiene, debido a que notamos una diferencia entre las transmisiones del tipo automático y manual cuando estudiamos los gases de CO2. Por lo que se puede concluir que las transmisiones automáticas emiten, en promedio, mayor cantidad de gases de CO2 que uno de transmisión manual.
#
# Para el objetivo principal todavía se requiere trabajar con una técnica de minería de datos, pero en este trabajo pudimos darnos cuenta de que las variables de la base sí se relacionan con las emisiones de una manera directa, por lo que se sigue pensando que, con una regresión lineal que involucre distintas variables, podremos predecir las emisiones de CO2 y cumplir con el objetivo.

# %% [markdown]
# ## Práctica de técnicas de minería

# %% [markdown]
# Empezaremos por leer la base de datos que trabajaremos

# %%
base_nueva
for i in range(0,7385):     # Gracias a que ya sabemos el tamaño de la base de datos
    if base_nueva['Transmission'][i][0]=='A':
        base_nueva['Transmission'][i]='Automatic'
    else:
        if base_nueva['Transmission'][i][0]=='M':
            base_nueva['Transmission'][i]='Manual'
base_nueva
# Out:
#        Make  ... CO2_Emissions(g/km)
# 0     ACURA  ...                 196
# 4373  ACURA  ...                 251
# 4372  ACURA  ...                 259
# 4371  ACURA  ...                 192
# 5454  ACURA  ...                 199
# ...     ...  ...                 ...
# 5442  VOLVO  ...                 216
# 5441  VOLVO  ...                 206
# 5440  VOLVO  ...                 220
# 5438  VOLVO  ...                 221
# 7384  VOLVO  ...                 248
#
# [7385 rows x 11 columns]

# %% [markdown]
# ## Detección de outliers

# %% [markdown]
# #### ¿Qué son los outliers?
#
# Es una observación anormal en una muestra estadística o serie temporal que afecta la estimación de parámetros.
#
# Identificar “outliers” es fundamental si se desea realizar un análisis descriptivo, ya que estos forman parte de la estadística descriptiva.
#
# Los valores extremos se denominan “outliers” en inglés
# Los valores internos se denominan “insiders” en inglés.
#
# #### Significado de los outliers
#
# Tener este tipo de valores pueden significar:
# 1. ERROR: Errores a la hora de capturar datos
# 2. CASOS EXTREMOS: Momentos o casos fuera de lo esperado, casos anómalos

# %% [markdown]
# ### Identificando outliers
#
# Para esto, se pondrá en discusion la presencia de outliers en los valores de nuestra variable **CO2_Emissions(g/km)**
# Podemos identificar la presencia de este tipo de datos mediante un diagrama de caja o boxplot:

# %%
plt.boxplot(base_nueva['CO2_Emissions(g/km)'], vert=False)
plt.show()

# %% [markdown]
# De la gráfica anterior, es posible detectar la presencia de estos datos. Para esto nos basta con recordar que nos grafica un diagrama de caja:
# Se sabe que los lados externos del diagrama boxplot representan tanto el valor mínimo como el valor máximo, por lo que los valores que estén fuera del mínimo y máximo, son considerados **outliers**.

# %% [markdown]
# Con lo observado anteriormente, se conluye que hay una presencia de **outliers**. Se procederá a realizar una busqueda de dichos datos.

# %%
BI=base_nueva['CO2_Emissions(g/km)'].quantile(.25)-1.5*(base_nueva['CO2_Emissions(g/km)'].quantile(.75)-base_nueva['CO2_Emissions(g/km)'].quantile(.25))
BS=base_nueva['CO2_Emissions(g/km)'].quantile(.75)+1.5*(base_nueva['CO2_Emissions(g/km)'].quantile(.75)-base_nueva['CO2_Emissions(g/km)'].quantile(.25))
ubicacion_outliers=(base_nueva['CO2_Emissions(g/km)']<BI)|(base_nueva['CO2_Emissions(g/km)']>BS)
print('Ubicación de outliers\n',ubicacion_outliers)
# Out:
# Ubicación de outliers
#  0       False
# 4373    False
# 4372    False
# 4371    False
# 5454    False
#         ...
# 5442    False
# 5441    False
# 5440    False
# 5438    False
# 7384    False
# Name: CO2_Emissions(g/km), Length: 7385, dtype: bool

# %% [markdown]
# Ahora, se realiza una visualización de los datos que son considerados outliers, en este caso se filtra de la base de datos original aquellos que cumplan dicha condición:

# %%
outliers=base_nueva[ubicacion_outliers]
outliers
# Out:
#                Make  ... CO2_Emissions(g/km)
# 3331   ASTON MARTIN  ...                 450
# 48             AUDI  ...                 409
# 52             AUDI  ...                 409
# 5511        BENTLEY  ...                 465
# 75          BENTLEY  ...                 437
# ...             ...  ...                 ...
# 5126  MERCEDES-BENZ  ...                 473
# 5125  MERCEDES-BENZ  ...                 419
# 4049  MERCEDES-BENZ  ...                 467
# 4048  MERCEDES-BENZ  ...                 413
# 5161  MERCEDES-BENZ  ...                 410
#
# [80 rows x 11 columns]

# %% [markdown]
# Continuando, se visualiza la otra parte de nuestra base, es decir, aquellos datos que no son considerados outliers:

# %%
ubicacion_sin_outliers=(base_nueva['CO2_Emissions(g/km)']>=BI)&(base_nueva['CO2_Emissions(g/km)']<=BS)
sin_outliers=base_nueva[ubicacion_sin_outliers]
sin_outliers
# Out:
#        Make  ... CO2_Emissions(g/km)
# 0     ACURA  ...                 196
# 4373  ACURA  ...                 251
# 4372  ACURA  ...                 259
# 4371  ACURA  ...                 192
# 5454  ACURA  ...                 199
# ...     ...  ...                 ...
# 5442  VOLVO  ...                 216
# 5441  VOLVO  ...                 206
# 5440  VOLVO  ...                 220
# 5438  VOLVO  ...                 221
# 7384  VOLVO  ...                 248
#
# [7305 rows x 11 columns]

# %% [markdown]
# Dado el filtro anterior, se prosigue a realizar nuevamente un chequeo para verificar que dichos datos ya se hayan eliminado:

# %%
plt.boxplot(sin_outliers['CO2_Emissions(g/km)'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3c15ebcd50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f3c15ec2e10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3c15ecae50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3c15eca910>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f3c15ec2390>,
#   <matplotlib.lines.Line2D at 0x7f3c15ec28d0>]}

# %% [markdown]
# De lo anterior, se nota que aún se tiene la presencia de dichos datos, por lo que se procede a realizar nuevamente una eliminación de estos datos repitiendo los datos hechos anteriormente.

# %% [markdown]
# Visualizando la ubicación de los datos outliers:

# %%
BI=sin_outliers['CO2_Emissions(g/km)'].quantile(.25)-1.5*(sin_outliers['CO2_Emissions(g/km)'].quantile(.75)-sin_outliers['CO2_Emissions(g/km)'].quantile(.25))
BS=sin_outliers['CO2_Emissions(g/km)'].quantile(.75)+1.5*(sin_outliers['CO2_Emissions(g/km)'].quantile(.75)-sin_outliers['CO2_Emissions(g/km)'].quantile(.25))
ubicacion_outliers2=(sin_outliers['CO2_Emissions(g/km)']<BI)|(sin_outliers['CO2_Emissions(g/km)']>BS)
print('Ubicación de outliers\n',ubicacion_outliers2)
# Out:
# Ubicación de outliers
#  0       False
# 4373    False
# 4372    False
# 4371    False
# 5454    False
#         ...
# 5442    False
# 5441    False
# 5440    False
# 5438    False
# 7384    False
# Name: CO2_Emissions(g/km), Length: 7305, dtype: bool

# %% [markdown]
# Continuando, se observa aquellos datos que no son considerados outliers en nuestra base:

# %%
ubicacion_sin_outliers2=(sin_outliers['CO2_Emissions(g/km)']>=BI)&(sin_outliers['CO2_Emissions(g/km)']<=BS)
sin_outliers2=sin_outliers[ubicacion_sin_outliers2]
sin_outliers2
# Out:
#        Make  ... CO2_Emissions(g/km)
# 0     ACURA  ...                 196
# 4373  ACURA  ...                 251
# 4372  ACURA  ...                 259
# 4371  ACURA  ...                 192
# 5454  ACURA  ...                 199
# ...     ...  ...                 ...
# 5442  VOLVO  ...                 216
# 5441  VOLVO  ...                 206
# 5440  VOLVO  ...                 220
# 5438  VOLVO  ...                 221
# 7384  VOLVO  ...                 248
#
# [7298 rows x 11 columns]

# %% [markdown]
# Se verifica nuevamente que se hayan eliminado los datos outliers por completo:

# %%
plt.boxplot(sin_outliers2['CO2_Emissions(g/km)'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f3c15e3d590>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f3c15e41650>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f3c15e48690>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f3c15e48150>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f3c15e3db90>,
#   <matplotlib.lines.Line2D at 0x7f3c15e41110>]}

# %% [markdown]
# Tomando en cuenta que se elimino la presencia outliers encontrados, se obtiene una base lista para poder trabajarla:

# %%
base_CO2=sin_outliers2
base_CO2
# Out:
#        Make  ... CO2_Emissions(g/km)
# 0     ACURA  ...                 196
# 4373  ACURA  ...                 251
# 4372  ACURA  ...                 259
# 4371  ACURA  ...                 192
# 5454  ACURA  ...                 199
# ...     ...  ...                 ...
# 5442  VOLVO  ...                 216
# 5441  VOLVO  ...                 206
# 5440  VOLVO  ...                 220
# 5438  VOLVO  ...                 221
# 7384  VOLVO  ...                 248
#
# [7298 rows x 11 columns]

# %% [markdown]
# # Técnica de minería: Regresión lineal

# %% [markdown]
# La técnica que se decidió emplear en el trabajo para contestar o resolver el objetivo principal es la regresión lineal. Como ya se sabe, el objetivo de la regresión lineal es predecir el valor de una variable por medio del valor de otra(s). En el objetivo principal se dice que se quiere predecir las emisiones de CO2, por lo que se puede hacer uso de la regresión lineal para cumplir con esto. La regresión lineal involucra dos tipos de variables: dependiente e independiente; la variable que se quiere predecir es la dependiente, en nuestro caso el valor de las emisiones de CO2, mientras que las variables independientes son aquellas que se utilizarán para explicar el comportamiento de la variable dependiente, en la base se cuenta con distintas variables para hacer uso de ellas y modelar la regresión. En resumen, se hace uso de esta técnica debido a que será de utilidad para predecir las emisiones de CO2 y se cuenta con todas las componentes necesarias para realizarla.
#
# Otro punto válido para trabajar con una regresión lineal es que se tienen suficientes variables independientes para intentar diversos modelos que las involucren. Las variables se relacionan de buena manera con la variable dependiente (emisiones de CO2), lo que nos indica que las emisiones podrían ser explicadas con alguna(s) de estas variables por medio de un modelo de regresión lineal múltiple (la relación se mostró en el avance 2 del PIA).

# %% [markdown]
# ## Regresión lineal múltiple en Python
# *Es importante mencionar que la siguiente información (código) fue obtenida de una fuente externa, la cual estará anexada al final de documento con sus respectivas referencias.*

# %% [markdown]
# Antes de empezar a trabajar con la regresión lineal debemos preguntarnos "¿Por qué funcionaría una regresión con mis datos?". De antemano sabemos que las variables de la base están fuertemente relacionadas, lo que nos indica que una variable o un conjunto de variables podrían explicar de una buena manera el comportamiento de las emisiones de CO2 de los automóviles e intentar predecirlas por medio de un modelo de regresión lineal que usualmente son aplicados en estos casos.
#
# De la misma manera, se puede suponer que las variables independientes están involucradas de manera directa con las emisiones. Por ejemplo, a mayor número de cilindros en un automóvil sabemos que implica que necesita más combustible (producirá más emisiones); a mayor tamaño de motor se necesita de igual forma mayor combustible (puesto que está medido en litros); entre otros casos. Por lo que podemos imaginar que un conjunto de variables de este estilo pueden predecir las emisiones de CO2 que un vehículo generará dadas sus características básicas.
#
# Una vez establecido esto, podemos empezar con el análisis de regresión lineal múltiple que proponemos.

# %% [markdown]
# ### Datos

# %% [markdown]
# Lo primero que se tiene que hacer es leer la base de datos más nueva que se tiene, en este caso es aquella que resulta después de las modificaciones y eliminaciones de columnas.

# %%
baseCO2 = base_CO2

# %% [markdown]
# Se debe comprobar que la base se haya guardado correctamente en la variable:

# %%
baseCO2
# Out:
#        Make  ... CO2_Emissions(g/km)
# 0     ACURA  ...                 196
# 4373  ACURA  ...                 251
# 4372  ACURA  ...                 259
# 4371  ACURA  ...                 192
# 5454  ACURA  ...                 199
# ...     ...  ...                 ...
# 5442  VOLVO  ...                 216
# 5441  VOLVO  ...                 206
# 5440  VOLVO  ...                 220
# 5438  VOLVO  ...                 221
# 7384  VOLVO  ...                 248
#
# [7298 rows x 11 columns]

# %% [markdown]
# De esta base, la variable dependiente será: CO2_Emissions(g/km); mientras que las posibles variables independientes serán: Engine_Size(L), Cylinders, Fuel_Consumption_City(L/100 km), Fuel_Consumption_Hwy(L/100 km) y Fuel Consumption Comb (L/100 km). Es importante recalcar que estas variables son numéricas. Como se estudió previamente, estas variables guardan una relación fuerte entre ellas por lo que nos serán de utilidad para ajustar un modelo de regresión lineal.

# %% [markdown]
# ### Ajuste del modelo

# %% [markdown]
# En el objetivo principal se estableció que se quiere predecir las emisiones de CO2; esto se logra utilizando las diversas variables que se tienen en la base de datos. Sin embargo, una vez que se obtiene el modelo, ¿cómo comprobaríamos que predice correctamente?, esto es un problema puesto que necesitaríamos una serie de datos que contengan información para cada una de las variables involucradas en el modelo. Para no tener algún inconveniente con esto último, se suele separar la información original que en una proporción de 80-20, donde el 80% de los datos son designados para la elaboración del modelo y el 20% son dirigidos hacia la parte de intentar predecir dicho valor que se tiene.
#
# Una vez conociendo esto, se procede a separar la información original.

# %%
# División de los datos
X = baseCO2[['Engine_Size(L)', 'Cylinders', 'Fuel_Consumption_City(L/100 km)', 'Fuel_Consumption_Hwy(L/100 km)', 'Fuel Consumption Comb (L/100 km)']]
y = baseCO2['CO2_Emissions(g/km)']

X_train, X_test, y_train, y_test = train_test_split(
                                        X,
                                        y.values.reshape(-1,1),
                                        train_size   = 0.8,
                                        random_state = 1234,
                                        shuffle      = True
                                    )

# %% [markdown]
# Donde las variables "train" nos ayudarán a elaborar el modelo y las variables "test" nos ayudarán a comprobar qué tanto ajusta nuestro modelo a valores reales que ya se contienen en la base.

# %% [markdown]
# Para la creación del modelo de regresión existen diversas alternativas en Python; sin embargo, se optó por trabajarlo por medio de matrices. A la matriz de los predictores se le tiene que añadir una columna de 1s para el intercepto del modelo. Las intrucciones quedan de la siguiente manera:

# %%
X_train = sm.add_constant(X_train, prepend=True)
modelo = sm.OLS(endog=y_train, exog=X_train,)
modelo = modelo.fit()
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                     7752.
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        04:18:06   Log-Likelihood:                -25765.
# No. Observations:                5838   AIC:                         5.154e+04
# Df Residuals:                    5832   BIC:                         5.158e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Por medio del summary obtenemos todos los datos pertinentes a una regresión lineal, como se ve a simple vista incluye valores que nos serán de suma importancia para analizar cada aspecto del modelo.
#
# Lo primero que se debe mencionar es que este modelo está considerando todas las variables númericas anteriormente mencionadas, es decir, no se hizo una discriminación entre ellas ya que primero se quiere revisar cómo trabajan en conjunto.
#
# Una vez aclarado esto, se debe revisar si el modelo es significativo, ya que si no lo es, no tendríamos porqué usarlo. Para probar esto, se realiza una prueba de hipótesis en la que la hipótesis nula es que la regresión no es significativa, mientras que la hipótesis alternativa es que la regresión es significativa. Al tener un p valor = 0.0, podemos decir que, con 95% de confianza, la regresión es signficativa en vista que p valor = 0.0 < alpha = 0.05. Por tanto, el modelo es significativo.
#
# El modelo ha resultado significativo, el siguiente paso es revisar las características de dicho modelo, entre las que destacan:
# + **Ajuste del modelo:** El ajuste obtenido por este modelo es del 86.9%. El modelo explica el 86.9% de la variabilidad de los datos. En la práctica, se considera que 86.9% es un buen ajuste.
# + **Coeficientes de los modelos:** Es importante voltear a ver los coeficientes para cada variable regresora y la constante, puesto que estos son los que conformarán la ecuación para predecir a las emisiones de CO2.
# + **P valor para cada variable:** El p valor de las variables nos indica qué tanto contribuyen en significancia al modelo. Un p valor alto nos dice ausencia de significancia y un valor bajo, lo contrario.
#
# Se puede notar que el p valor obtenido para las variables Fuel_Consumption_City(L/100 km), Fuel_Consumption_Hwy(L/100 km) y Fuel Consumption Comb (L/100 km) es muy grande (mayor a un alpha de 0.05). Esto nos dice que estas variables no contribuyen de manera significativa a nuestro modelo, por lo que podemos eliminarlas sin problema alguno. Nosotros dejaremos la última variable puesto que su p valor es el menor entre ellos tres y queremos comprobar si disminuye al eliminar las otras.

# %% [markdown]
# Se crea un nuevo modelo excluyendo las variables que no son significativas:

# %%
# Se eliminan las columnas del conjunto de train y test
X_train = X_train.drop(columns = 'Fuel_Consumption_City(L/100 km)')
X_train = X_train.drop(columns = 'Fuel_Consumption_Hwy(L/100 km)')
X_test  = X_test.drop(columns = 'Fuel_Consumption_City(L/100 km)')
X_test  = X_test.drop(columns = 'Fuel_Consumption_Hwy(L/100 km)')


X_train = sm.add_constant(X_train, prepend=True)
modelo  = sm.OLS(endog=y_train, exog=X_train,)
modelo  = modelo.fit()
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                 1.292e+04
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        04:18:13   Log-Likelihood:                -25766.
# No. Observations:                5838   AIC:                         5.154e+04
# Df Residuals:                    5834   BIC:                         5.157e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Como se tiene un p valor = 0.0, el modelo sigue siendo significativo, lo cual es bueno; además, es importante recalcar que el ajuste obtenido por el modelo que excluye a las variables que no son significativas es el mismo que el del modelo anterior (86.9%), por lo que explica la misma variabilidad de los datos. Sin embargo, ahora podemos notar que el p valor obtenido para cada variable (0.0 en todos los casos) es menor a nuestro alpha de 0.05, por lo que podemos decir que las tres variables involucradas en el modelo contribuyen significativamente a este.
#
# Este modelo es mejor que el anterior aunque obtengamos el mismo ajuste. Esto se debe a que con una menor cantidad de variables podemos explicar la misma variabilidad. Además, también resulta más sencillo de interpretar y facilita el análisis.

# %% [markdown]
# ### Intervalos de confianza para los coeficientes

# %% [markdown]
# Otra de los factores en el que debemos prestar atención es en los intervalos de confianza de los coeficientes para las variables. Estos intervalos nos revelan información valiosa. Si revisamos el intervalo del coeficiente constante, podremos saber si existe evidencia de regresión al origen, así como también se puede comprender entre qué valores estará comprendido dicho valor con cierta confianza.

# %%
intervalos_ci = modelo.conf_int(alpha=0.05)
intervalos_ci.columns = ['2.5%', '97.5%']
intervalos_ci
# Out:
#                                        2.5%      97.5%
# const                             52.519203  57.502463
# Engine_Size(L)                     4.755525   7.021241
# Cylinders                          5.501222   7.077779
# Fuel Consumption Comb (L/100 km)  12.536129  13.176253

# %% [markdown]
# Con estos intervalos del 95% de confianza, podemos confirmar que no existe evidencia de regresión al origen puesto que el intervalo de la constante no involucra al cero; esto nos dice que no se creará otro modelo de regresión. Además, podemos estudiar entre qué valores oscilará el coeficiente de las demás variables.

# %% [markdown]
# ### Residuales

# %% [markdown]
# Una de las últimas partes importantes a la hora de revisar un modelo es estudiar el comportamiento de los residuales. Como se estudió en clase, existen cuatro supuestos sobre estos que deben ser probados con el fin de determinar si el modelo tiene un grado mayor de significancia del que ya tiene.
#
# Antes de probar los supuestos, se deben calcular los residuales, los cuales salen al realizar la resta del valor estimado menos el valor real, el resultado será el residuo. Cada uno de los valores tiene un residuo, el objetivo es estudiar dichos residuos.

# %%
y_train = y_train.flatten()
prediccion_train = modelo.predict(exog = X_train)
residuos_train   = prediccion_train - y_train

# %% [markdown]
# Una vez que se tienen los residuales, se comprobará que cumplan con los siguientes supuestos:
# + Media cero
# + Varianza constante
# + Normalidad
# + Incorrelación

# %% [markdown]
# Como no existe una prueba definida para probar la **media cero**, se suele calcular un promedio de los residuales y, si se encuentra cercano al cero, se acepta el cumplimiento del supuesto.

# %%
residuos_train.mean()
# Out:
# -2.824693393048083e-13

# %% [markdown]
# Como se puede ver, el resultado obtenido es cercano a cero. Por lo tanto, se cumple el supuesto de media cero.

# %% [markdown]
# Para la prueba de **varianza constante** se intentará probar que la gráfica de dispersión no muestre un patrón aparente, ya que si se muestra un patrón, nos estaría diciendo que la varianza no es constante ya que tiende hacia algo. La gráfica a utilizar es el de las predicciones vs los residuales.

# %%
fig, ax = plt.subplots()
ax.scatter(prediccion_train, residuos_train)
plt.axhline(y=0)
ax.set_title('Residuos del modelo vs predicción', fontsize = 10, fontweight = "bold")
ax.set_xlabel('Predicción')
ax.set_ylabel('Residuo')
plt.show()

# %% [markdown]
# El supuesto de varianza constante se puede "rescatar" a raíz de esta gráfica, puesto que no se identifica un patrón sumamente claro. Es verdad que la dispersión de los datos pareciera formar una serie de líneas que cruzan el cero, sin ambargo esto no parece una secuencia o algo por el estilo. Por lo que el supuesto de varianza constante se "rescata" para seguir probando los demás supuestos, así que se cumple.

# %% [markdown]
# Para probar la **normalidad** de los residuales basta con realizar una prueba de hipótesis donde decimos que H0 es que los residuales provienen de una distribución normal y H1 es que los residuales provienen de otra distribución. Para encontrar el p valor perteneciente, se utiliza la prueba conocida de shapiro test utilizada frecuentemente en estadística con el mismo fin. Haciendo esto, obtenemos lo siguiente:

# %%
shapiro_test = stats.shapiro(residuos_train)
shapiro_test
# Out:
# (0.8818002939224243, 0.0)

# %% [markdown]
# Al obtener un p valor = 0.0, se tiene que rechazar H0. Por lo tanto decimos que los residuales no siguen una distribución normal, por lo que no cumplen este supuesto.

# %% [markdown]
# No se necesita analizar la **incorrelación** de los residuales ya que sólo nos importa determinar si cumplen los cuatro supuestos a la vez o no. Como se comentó en un inicio, en caso de cumplirse los cuatro supuestos le daría un extra de importancia al modelo encontrado, pero para este modelo no se cumplen.
#
# Se sospecha que el problema con los supuestos se origina a raíz de la alta correlación entre variables que se encontró previamente. Al tener una fuerte correlación entre variables (no necesariamente con la dependiente) tenemos un problema con los VIF, ya que estos saldrán altos y eso no es lo que se busca. Sin embargo, al no poder cambiar el comportamiento de las variables y su relación, se tomará la parte positiva que es el ajuste del modelo del 86.9% que explica de buena manera la variabilidad de los datos.

# %% [markdown]
# ### Predicciones del modelo

# %% [markdown]
# Como se estableció en un inicio, una parte importante de los modelos es el de predecir los valores para nuevos datos. En nuestro caso, deliberadamente, dejamos el 20% de los valores a un lado con el fin de utilizarlos como valores a predecir. Es decir, predecir estos valores que tenemos es el objetivo del modelo para medir qué tanto funcionarían aplicados en la realidad.
#
# La siguiente serie de instrucciones nos permiten conocer los intervalos de confianza para cada predicción, así como el error cuadrático medio, entre otras cosas.

# %%
predicciones = modelo.get_prediction(exog = X_train).summary_frame(alpha=0.05)
predicciones.head(4)
# Out:
#             mean   mean_se  ...  obs_ci_lower  obs_ci_upper
# 4457  210.691276  0.604285  ...    171.495317    249.887234
# 117   294.509349  0.503328  ...    255.318873    333.699826
# 2512  261.792212  0.285176  ...    222.610171    300.974254
# 5302  232.451037  0.464860  ...    193.262387    271.639687
#
# [4 rows x 6 columns]

# %% [markdown]
# ### Error del test

# %%
X_test = sm.add_constant(X_test, prepend=True)
predicciones = modelo.predict(exog = X_test)
rmse = mean_squared_error(
        y_true  = y_test,
        y_pred  = predicciones,
        squared = False
       )
print("")
print(f"El error (RMSE) de test es: {rmse}")
# Out:
# El error (RMSE) de test es: 19.17383108376155

# %% [markdown]
# ### Interpretación del modelo

# %% [markdown]
# La ecuación del modelo de regresión lineal múltiple que se obtuvo finalmente es:
#
# $$Emisiones de CO2 (g/km) = 5.8884EngineSize(L) + 6.2895Cylinder + 12.8562FuelConsumptionComb(L/100 km) + 55.0108$$
#
# Es capaz de explicar el 86.9% de la variabilidad de las emisiones de CO2(g/km) que los automóviles emiten. La prueba de significancia del modelo resultó aprobatoria, por tanto, el modelo de regresión es significativo. Además, podemos decir que el tamaño del motor, el número de cilindros del vehículo y el consumo combinado de combustible(L/100km) están relacionados con las emisiones de CO2 de un automóvil y contribuyen significativamente al modelo.
#
# A pesar de todo esto, no se satisface la condición de normalidad en los residuales, por lo que los intervalos de confianza para los coeficientes y las predicciones no son tan fiables como se esperaría.
#
# Finalmente, el error cuadrático medio del modelo es de 19.17., lo que nos indica que las predicciones del modelo final se alejan, en promedio, 19.17(g/km) del valor real.

# %% [markdown]
# ## Métricas de evaluación

# %% [markdown]
# ### Error cuadrático medio
# Mide el promedio de los errores al cuadrado, es decir, la diferencia entre el estimador y lo que se estima. Nos indica, en promedio, cuánto nos desvíamos del valor real.
#
# Esta métrica es de las más importantes puesto que resume todo el análisis de un modelo. Básicamente, no importa si tus residuos cumplen todos los supuestos o si tienes un ajuste superior al 90%, si tu error cuadrático medio es demasiado alto, entonces tus predicciones no serán muy acertadas, por ello lo que se busca en este estimador es tener el valor más pequeño posible porque nos diría que no existe mucha diferencia entre las predicciones y el valor real. Se calcula de la siguiente manera:

# %%
X_test = sm.add_constant(X_test, prepend=True)
predicciones = modelo.predict(exog = X_test)
rmse = mean_squared_error(
        y_true  = y_test,
        y_pred  = predicciones,
        squared = False
       )
print("")
print(f"El error (RMSE) de test es: {rmse}")
# Out:
# El error (RMSE) de test es: 19.17383108376155

# %% [markdown]
# El resultado se suele dejar a interpretación del investigador, esto nos quiere decir que depende de la persona decidir si para él este valor es elevado o no, dependiendo de lo que se está buscando.

# %% [markdown]
# ### R cuadrado o coeficiente de determinación
# Esta métrica representa la parte de la varianza de la variable dependiente explicada por las variables independientes del modelo. Mide la fuerza de la relación entre su modelo y la variable dependiente. Cuanto más cerca de 1 se sitúe su valor, mayor será el ajuste del modelo a la variable que estamos intentando explicar. Por el otro lado, cuanto más cerca de cero, menos ajustado estará del modelo y, por tanto, menos fiable será.
#
# Resulta importante conocer esta métrica puesto que habla mucho acerca de nuestro modelo. A mejores ajustes, mejores predicciones. Una ecuación de regresión bien ajustada a los valores nos indica que la relación queda bien explicada y por ende la variabilidad.
# Se calcula desde el inicio de la regresión en el summary del modelo:

# %%
X_train = sm.add_constant(X_train, prepend=True)
modelo  = sm.OLS(endog=y_train, exog=X_train,)
modelo  = modelo.fit()
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                 1.292e+04
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):               0.00
# Time:                        04:27:14   Log-Likelihood:                -25766.
# No. Observations:                5838   AIC:                         5.154e+04
# Df Residuals:                    5834   BIC:                         5.157e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# En esta sección se encuentran dos R cuadrados. El primero es el R cuadrado "tradicional", nos indica el ajuste del modelo; sin embargo, suele emplearse cuando se trata de una regresión que involucra a sólo una variable independiente. Por otra parte, el R cuadrado ajustado, suele emplearse cuando se involucra a más de una variable independiente; de igual manera, nos indica el ajuste que realiza, así como la variabilidad que queda explicada.

# %% [markdown]
# ## Conclusión

# %% [markdown]
# Desde que se estableció el objetivo principal se pensó en utilizar una regresión linel múltiple con el fin de predecir y comprender el comportamiento de las emisiones de CO2 medidas en (g/km). Se tenía conocimiento de la regresión lineal puesto que ya se había llevado una clase de estadística en la que se aprendió sobre esto, más no se vio cómo aplicarlo en una base de datos en un lenguaje de programación, por ello es que desde primera instancia nos llamó la atención poder resolver esta problemática. Pensábamos que con las columnas que tenía nuestra base sería suficiente para poder explicar de manera adecuada las emisiones, puesto que, a primera instancia, se veía que las variables iban a relacionarse entre sí.
#
# A medida que fuimos revisando la base de datos, nos dimos cuenta que las variables se relacionaban fuertemente con la variable dependiente; sin embargo, no contábamos con que las variables independientes se relacionarían fuertemente entre ellas también. Esto causó un problema en el modelo de regresión que posteriormente elaboramos. Los VIF de las variables independientes salieron altos puesto que su correlación era alta, lo que hizo que los residuales no pudieran distribuírse de una manera normal y, a su vez, que no cumplieran con los supuestos establecidos.
#
# El modelo de regresión que encontramos fue bueno, tal como se pensó en un inicio. De hecho las variables involucradas fueron las que pensábamos iban a quedar, ya que el tamaño del motor y el número de cilindros son dos de las cosas que sabemos de antemano que afectan a las emisiones debido al consumo; así como el rendimiento (consumo) de combustible combinado, ya que junta a los dos tipos de rendimiento que se tienen por separado, por lo que teníamos en mente que esta variable podría ser una combinación lineal de las anteriores.
#
# Una parte importante para resolver los objetivos es la parte predictiva. Al inicio, ciertamente no se pensó en cómo íbamos a obtener el conjunto de datos que necesitamos para predecir las emisiones; sin embargo, logramos sacar adelante el trabajo gracias a la idea de separar nuestro conjunto en relación 80-20. De esta manera, reservamos el 20% de los datos. Este punto fue crucial para la investigación, ya que si quisiéramos predecir las emisiones de un automóvil, primero deberíamos conocer el tamaño del motor medido en litros, el número de cilindros, así como su rendimiento (consumo) combinado; las primeras dos características son algo sencillas de encontrar, sin embargo el tercer elemento no es tan natural conocerlo, por lo que se complicaría juntar información.
#
# Sin lugar a dudas la técnica de regresión lineal nos fue de gran ayuda para poder cumplir el objetivo principal que tenímaos planteado, ya que pudimos predecir las emisiones de CO2 correctamente, con un 86.9% de variabilidad explicada y sólo con una desviación de aproximadamente 19.1 unidades; lo cual creemos una buena aproximación considerando los problemas que tuvimos al inicio.
#
# Por otra parte, tenemos las métricas de evaluación que fueron de utilidad para poder medir el desempeño de nuestro modelo. Escogimos el R cuadrado puesto que es uno de los principales factores que se tienen que resaltar en un modelo para medir el ajuste de este, así como también el error cuadrático medio para conocer, en unidades reales, cuánto nos estamos alejando de nuestro objetivo en una manera cuantificada. Estas métricas nos permiten comparar nuestro modelo con algun otro, tal y como se hizo durante el mismo trabajo (sólo que el R cuadrado fue el mismo); lo que ocasiona que el modelo pueda mejorarse y encontrar mejores resultados. Estas métricas resultan sencillas de comparar ya que son números. Un valor mayor de R cuadrada nos indica que un modelo tiene más ajuste que otro, mientras que un error cruadrático medio menor nos dice que, en promedio, las predicciones no difieren tanto de los valores reales. Por lo que resulta sencillo comparar nuestro trabajo con uno similar.

# %% [markdown]
# ### Ideas para mejorar el resultado final

# %% [markdown]
# A este punto de la investigación, en donde ya identificamos y eliminamos los datos atípicos, generamos la ecuación del modelo de regresión lineal múltiple y nos dimos cuenta qué variables no fueron tan significativas; se nos ocurrieron algunas ideas para mejorar los resultado final, tales como:
#
#
#
# *   Agregar Variables al modelo que expliquen las emisiones de C02 de los automóviles pero que no se relacionen con otras (ya que  en el modelo que generamos las variables entre si están muy relacionadas) puesto a que esta problemática causaría problemas en la ecuación del modelo de regresión lineal múltiple y afecta los supuestos, en donde uno de ellos es que no exista multicolinealidad.
# *   Probar diferentes modelos y compararlos entre ellos, ya sea generando un modelo para cierto número de variables y ver cuál es el mejor modelo con el fin de no recabar más datos pero sí determinar el mejor modelo de las opciones que tenemos puesto que en esta ocasión solo se compararon dos.

# %% [markdown]
# ## Referencias utilizadas

# %% [markdown]
# - [Técnica de minería: Regresión lineal](https://www.cienciadedatos.net/documentos/py10-regresion-lineal-python.html)
# - [Métricas de evaluación: Regresión lineal](https://docs.microsoft.com/es-es/azure/machine-learning/classic/evaluate-model-performance)
